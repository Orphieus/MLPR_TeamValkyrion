# %%
# printing current python version
# and the version of the installed modules
import sys
import pkg_resources
import platform
import subprocess
import os
import sysconfig
import logging
import json
import re


def get_python_version():
    """Get the current Python version."""
    return sys.version.split()[0]

print("Python version:", get_python_version())
# Out:
# Python version: 3.13.2
# /var/folders/kz/pzq5xgxj58bb6nqgtmckp_x00000gn/T/ipykernel_72694/3691712826.py:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
import os
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from sklearn.utils import resample, shuffle
from sklearn.model_selection import train_test_split
from PIL import Image
import numpy as np

# %%
import os

def rename_images_and_labels(image_dir, label_dir):
    """
    Rename all images in `image_dir` and corresponding label files in `label_dir` to a consistent format `photo<number>`.

    Args:
        image_dir (str): Path to the directory containing image files.
        label_dir (str): Path to the directory containing label files.
    """
    photo_count = 1  # Start numbering from 1

    # Create a list of valid image extensions
    valid_extensions = [".png", ".jpg", ".jpeg"]

    # Process images and labels
    for image_file in os.listdir(image_dir):
        image_path = os.path.join(image_dir, image_file)

        # Skip non-files and unsupported formats
        if not os.path.isfile(image_path) or not any(image_file.endswith(ext) for ext in valid_extensions):
            continue

        # Check for a corresponding label file
        label_file = os.path.splitext(image_file)[0] + ".txt"
        label_path = os.path.join(label_dir, label_file)

        # If the label exists, rename both
        if os.path.exists(label_path):
            new_base_name = f"yayphoto{photo_count}"
            
            # Rename the image
            new_image_name = f"{new_base_name}{os.path.splitext(image_file)[1]}"
            new_image_path = os.path.join(image_dir, new_image_name)
            os.rename(image_path, new_image_path)

            # Rename the label
            new_label_name = f"{new_base_name}.txt"
            new_label_path = os.path.join(label_dir, new_label_name)
            os.rename(label_path, new_label_path)

            print(f"Renamed: {image_file} -> {new_image_name}")
            print(f"Renamed: {label_file} -> {new_label_name}")

            # Increment the counter
            photo_count += 1
        else:
            print(f"No matching label found for image: {image_file}")

if __name__ == "__main__":
    # Specify the paths to the image and label directories
    image_dir = "/Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images"
    label_dir = "/Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/labels"

    rename_images_and_labels(image_dir, label_dir)
# Out:
# Renamed: photo548.jpg -> yayphoto1.jpg
# Renamed: photo548.txt -> yayphoto1.txt
# Renamed: photo212.jpg -> yayphoto2.jpg
# Renamed: photo212.txt -> yayphoto2.txt
# Renamed: photo574.jpg -> yayphoto3.jpg
# Renamed: photo574.txt -> yayphoto3.txt
# Renamed: photo560.jpg -> yayphoto4.jpg
# Renamed: photo560.txt -> yayphoto4.txt
# Renamed: photo206.jpg -> yayphoto5.jpg
# Renamed: photo206.txt -> yayphoto5.txt
# Renamed: photo48.jpg -> yayphoto6.jpg
# Renamed: photo48.txt -> yayphoto6.txt
# Renamed: photo60.jpg -> yayphoto7.jpg
# Renamed: photo60.txt -> yayphoto7.txt
# Renamed: photo74.jpg -> yayphoto8.jpg
# Renamed: photo74.txt -> yayphoto8.txt
# Renamed: photo428.jpg -> yayphoto9.jpg
# Renamed: photo428.txt -> yayphoto9.txt
# Renamed: photo366.jpg -> yayphoto10.jpg
# Renamed: photo366.txt -> yayphoto10.txt
# Renamed: photo400.jpg -> yayphoto11.jpg
# Renamed: photo400.txt -> yayphoto11.txt
# Renamed: photo414.jpg -> yayphoto12.jpg
# Renamed: photo414.txt -> yayphoto12.txt
# Renamed: photo372.jpg -> yayphoto13.jpg
# Renamed: photo372.txt -> yayphoto13.txt
# Renamed: photo399.jpg -> yayphoto14.jpg
# Renamed: photo399.txt -> yayphoto14.txt
# Renamed: photo158.jpg -> yayphoto15.jpg
# Renamed: photo158.txt -> yayphoto15.txt
# Renamed: photo602.jpg -> yayphoto16.jpg
# Renamed: photo602.txt -> yayphoto16.txt
# Renamed: photo164.jpg -> yayphoto17.jpg
# Renamed: photo164.txt -> yayphoto17.txt
# Renamed: photo170.jpg -> yayphoto18.jpg
# Renamed: photo170.txt -> yayphoto18.txt
# Renamed: photo616.jpg -> yayphoto19.jpg
# Renamed: photo616.txt -> yayphoto19.txt
# Renamed: photo171.jpg -> yayphoto20.jpg
# Renamed: photo171.txt -> yayphoto20.txt
# Renamed: photo617.jpg -> yayphoto21.jpg
# Renamed: photo617.txt -> yayphoto21.txt
# Renamed: photo603.jpg -> yayphoto22.jpg
# Renamed: photo603.txt -> yayphoto22.txt
# Renamed: photo165.jpg -> yayphoto23.jpg
# Renamed: photo165.txt -> yayphoto23.txt
# Renamed: photo159.jpg -> yayphoto24.jpg
# Renamed: photo159.txt -> yayphoto24.txt
# Renamed: photo398.jpg -> yayphoto25.jpg
# Renamed: photo398.txt -> yayphoto25.txt
# Renamed: photo415.jpg -> yayphoto26.jpg
# Renamed: photo415.txt -> yayphoto26.txt
# Renamed: photo373.jpg -> yayphoto27.jpg
# Renamed: photo373.txt -> yayphoto27.txt
# Renamed: photo367.jpg -> yayphoto28.jpg
# Renamed: photo367.txt -> yayphoto28.txt
# Renamed: photo401.jpg -> yayphoto29.jpg
# Renamed: photo401.txt -> yayphoto29.txt
# Renamed: photo429.jpg -> yayphoto30.jpg
# Renamed: photo429.txt -> yayphoto30.txt
# Renamed: photo75.jpg -> yayphoto31.jpg
# Renamed: photo75.txt -> yayphoto31.txt
# Renamed: photo61.jpg -> yayphoto32.jpg
# Renamed: photo61.txt -> yayphoto32.txt
# Renamed: photo49.jpg -> yayphoto33.jpg
# Renamed: photo49.txt -> yayphoto33.txt
# Renamed: photo561.jpg -> yayphoto34.jpg
# Renamed: photo561.txt -> yayphoto34.txt
# Renamed: photo207.jpg -> yayphoto35.jpg
# Renamed: photo207.txt -> yayphoto35.txt
# Renamed: photo213.jpg -> yayphoto36.jpg
# Renamed: photo213.txt -> yayphoto36.txt
# Renamed: photo575.jpg -> yayphoto37.jpg
# Renamed: photo575.txt -> yayphoto37.txt
# Renamed: photo549.jpg -> yayphoto38.jpg
# Renamed: photo549.txt -> yayphoto38.txt
# Renamed: photo239.jpg -> yayphoto39.jpg
# Renamed: photo239.txt -> yayphoto39.txt
# Renamed: photo88.jpg -> yayphoto40.jpg
# Renamed: photo88.txt -> yayphoto40.txt
# Renamed: photo205.jpg -> yayphoto41.jpg
# Renamed: photo205.txt -> yayphoto41.txt
# Renamed: photo563.jpg -> yayphoto42.jpg
# Renamed: photo563.txt -> yayphoto42.txt
# Renamed: photo577.jpg -> yayphoto43.jpg
# Renamed: photo577.txt -> yayphoto43.txt
# Renamed: photo211.jpg -> yayphoto44.jpg
# Renamed: photo211.txt -> yayphoto44.txt
# Renamed: photo588.jpg -> yayphoto45.jpg
# Renamed: photo588.txt -> yayphoto45.txt
# Renamed: photo77.jpg -> yayphoto46.jpg
# Renamed: photo77.txt -> yayphoto46.txt
# Renamed: photo63.jpg -> yayphoto47.jpg
# Renamed: photo63.txt -> yayphoto47.txt
# Renamed: photo359.jpg -> yayphoto48.jpg
# Renamed: photo359.txt -> yayphoto48.txt
# Renamed: photo371.jpg -> yayphoto49.jpg
# Renamed: photo371.txt -> yayphoto49.txt
# Renamed: photo417.jpg -> yayphoto50.jpg
# Renamed: photo417.txt -> yayphoto50.txt
# Renamed: photo403.jpg -> yayphoto51.jpg
# Renamed: photo403.txt -> yayphoto51.txt
# Renamed: photo365.jpg -> yayphoto52.jpg
# Renamed: photo365.txt -> yayphoto52.txt
# Renamed: photo629.jpg -> yayphoto53.jpg
# Renamed: photo629.txt -> yayphoto53.txt
# Renamed: photo615.jpg -> yayphoto54.jpg
# Renamed: photo615.txt -> yayphoto54.txt
# Renamed: photo173.jpg -> yayphoto55.jpg
# Renamed: photo173.txt -> yayphoto55.txt
# Renamed: photo167.jpg -> yayphoto56.jpg
# Renamed: photo167.txt -> yayphoto56.txt
# Renamed: photo601.jpg -> yayphoto57.jpg
# Renamed: photo601.txt -> yayphoto57.txt
# Renamed: photo198.jpg -> yayphoto58.jpg
# Renamed: photo198.txt -> yayphoto58.txt
# Renamed: photo199.jpg -> yayphoto59.jpg
# Renamed: photo199.txt -> yayphoto59.txt
# Renamed: photo166.jpg -> yayphoto60.jpg
# Renamed: photo166.txt -> yayphoto60.txt
# Renamed: photo600.jpg -> yayphoto61.jpg
# Renamed: photo600.txt -> yayphoto61.txt
# Renamed: photo614.jpg -> yayphoto62.jpg
# Renamed: photo614.txt -> yayphoto62.txt
# Renamed: photo172.jpg -> yayphoto63.jpg
# Renamed: photo172.txt -> yayphoto63.txt
# Renamed: photo628.jpg -> yayphoto64.jpg
# Renamed: photo628.txt -> yayphoto64.txt
# Renamed: photo402.jpg -> yayphoto65.jpg
# Renamed: photo402.txt -> yayphoto65.txt
# Renamed: photo364.jpg -> yayphoto66.jpg
# Renamed: photo364.txt -> yayphoto66.txt
# Renamed: photo370.jpg -> yayphoto67.jpg
# Renamed: photo370.txt -> yayphoto67.txt
# Renamed: photo416.jpg -> yayphoto68.jpg
# Renamed: photo416.txt -> yayphoto68.txt
# Renamed: photo358.jpg -> yayphoto69.jpg
# Renamed: photo358.txt -> yayphoto69.txt
# Renamed: photo62.jpg -> yayphoto70.jpg
# Renamed: photo62.txt -> yayphoto70.txt
# Renamed: photo76.jpg -> yayphoto71.jpg
# Renamed: photo76.txt -> yayphoto71.txt
# Renamed: photo589.jpg -> yayphoto72.jpg
# Renamed: photo589.txt -> yayphoto72.txt
# Renamed: photo576.jpg -> yayphoto73.jpg
# Renamed: photo576.txt -> yayphoto73.txt
# Renamed: photo210.jpg -> yayphoto74.jpg
# Renamed: photo210.txt -> yayphoto74.txt
# Renamed: photo204.jpg -> yayphoto75.jpg
# Renamed: photo204.txt -> yayphoto75.txt
# Renamed: photo562.jpg -> yayphoto76.jpg
# Renamed: photo562.txt -> yayphoto76.txt
# Renamed: photo238.jpg -> yayphoto77.jpg
# Renamed: photo238.txt -> yayphoto77.txt
# Renamed: photo89.jpg -> yayphoto78.jpg
# Renamed: photo89.txt -> yayphoto78.txt
# Renamed: photo566.jpg -> yayphoto79.jpg
# Renamed: photo566.txt -> yayphoto79.txt
# Renamed: photo200.jpg -> yayphoto80.jpg
# Renamed: photo200.txt -> yayphoto80.txt
# Renamed: photo214.jpg -> yayphoto81.jpg
# Renamed: photo214.txt -> yayphoto81.txt
# Renamed: photo572.jpg -> yayphoto82.jpg
# Renamed: photo572.txt -> yayphoto82.txt
# Renamed: photo228.jpg -> yayphoto83.jpg
# Renamed: photo228.txt -> yayphoto83.txt
# Renamed: photo99.jpg -> yayphoto84.jpg
# Renamed: photo99.txt -> yayphoto84.txt
# Renamed: photo72.jpg -> yayphoto85.jpg
# Renamed: photo72.txt -> yayphoto85.txt
# Renamed: photo66.jpg -> yayphoto86.jpg
# Renamed: photo66.txt -> yayphoto86.txt
# Renamed: photo599.jpg -> yayphoto87.jpg
# Renamed: photo599.txt -> yayphoto87.txt
# Renamed: photo412.jpg -> yayphoto88.jpg
# Renamed: photo412.txt -> yayphoto88.txt
# Renamed: photo374.jpg -> yayphoto89.jpg
# Renamed: photo374.txt -> yayphoto89.txt
# Renamed: photo360.jpg -> yayphoto90.jpg
# Renamed: photo360.txt -> yayphoto90.txt
# Renamed: photo406.jpg -> yayphoto91.jpg
# Renamed: photo406.txt -> yayphoto91.txt
# Renamed: photo348.jpg -> yayphoto92.jpg
# Renamed: photo348.txt -> yayphoto92.txt
# Renamed: photo176.jpg -> yayphoto93.jpg
# Renamed: photo176.txt -> yayphoto93.txt
# Renamed: photo610.jpg -> yayphoto94.jpg
# Renamed: photo610.txt -> yayphoto94.txt
# Renamed: photo604.jpg -> yayphoto95.jpg
# Renamed: photo604.txt -> yayphoto95.txt
# Renamed: photo162.jpg -> yayphoto96.jpg
# Renamed: photo162.txt -> yayphoto96.txt
# Renamed: photo638.jpg -> yayphoto97.jpg
# Renamed: photo638.txt -> yayphoto97.txt
# Renamed: photo189.jpg -> yayphoto98.jpg
# Renamed: photo189.txt -> yayphoto98.txt
# Renamed: photo188.jpg -> yayphoto99.jpg
# Renamed: photo188.txt -> yayphoto99.txt
# Renamed: photo639.jpg -> yayphoto100.jpg
# Renamed: photo639.txt -> yayphoto100.txt
# Renamed: photo605.jpg -> yayphoto101.jpg
# Renamed: photo605.txt -> yayphoto101.txt
# Renamed: photo163.jpg -> yayphoto102.jpg
# Renamed: photo163.txt -> yayphoto102.txt
# Renamed: photo177.jpg -> yayphoto103.jpg
# Renamed: photo177.txt -> yayphoto103.txt
# Renamed: photo611.jpg -> yayphoto104.jpg
# Renamed: photo611.txt -> yayphoto104.txt
# Renamed: photo349.jpg -> yayphoto105.jpg
# Renamed: photo349.txt -> yayphoto105.txt
# Renamed: photo361.jpg -> yayphoto106.jpg
# Renamed: photo361.txt -> yayphoto106.txt
# Renamed: photo407.jpg -> yayphoto107.jpg
# Renamed: photo407.txt -> yayphoto107.txt
# Renamed: photo413.jpg -> yayphoto108.jpg
# Renamed: photo413.txt -> yayphoto108.txt
# Renamed: photo375.jpg -> yayphoto109.jpg
# Renamed: photo375.txt -> yayphoto109.txt
# Renamed: photo598.jpg -> yayphoto110.jpg
# Renamed: photo598.txt -> yayphoto110.txt
# Renamed: photo67.jpg -> yayphoto111.jpg
# Renamed: photo67.txt -> yayphoto111.txt
# Renamed: photo73.jpg -> yayphoto112.jpg
# Renamed: photo73.txt -> yayphoto112.txt
# Renamed: photo229.jpg -> yayphoto113.jpg
# Renamed: photo229.txt -> yayphoto113.txt
# Renamed: photo98.jpg -> yayphoto114.jpg
# Renamed: photo98.txt -> yayphoto114.txt
# Renamed: photo215.jpg -> yayphoto115.jpg
# Renamed: photo215.txt -> yayphoto115.txt
# Renamed: photo573.jpg -> yayphoto116.jpg
# Renamed: photo573.txt -> yayphoto116.txt
# Renamed: photo567.jpg -> yayphoto117.jpg
# Renamed: photo567.txt -> yayphoto117.txt
# Renamed: photo201.jpg -> yayphoto118.jpg
# Renamed: photo201.txt -> yayphoto118.txt
# Renamed: photo571.jpg -> yayphoto119.jpg
# Renamed: photo571.txt -> yayphoto119.txt
# Renamed: photo217.jpg -> yayphoto120.jpg
# Renamed: photo217.txt -> yayphoto120.txt
# Renamed: photo203.jpg -> yayphoto121.jpg
# Renamed: photo203.txt -> yayphoto121.txt
# Renamed: photo565.jpg -> yayphoto122.jpg
# Renamed: photo565.txt -> yayphoto122.txt
# Renamed: photo559.jpg -> yayphoto123.jpg
# Renamed: photo559.txt -> yayphoto123.txt
# Renamed: photo65.jpg -> yayphoto124.jpg
# Renamed: photo65.txt -> yayphoto124.txt
# Renamed: photo71.jpg -> yayphoto125.jpg
# Renamed: photo71.txt -> yayphoto125.txt
# Renamed: photo59.jpg -> yayphoto126.jpg
# Renamed: photo59.txt -> yayphoto126.txt
# Renamed: photo405.jpg -> yayphoto127.jpg
# Renamed: photo405.txt -> yayphoto127.txt
# Renamed: photo363.jpg -> yayphoto128.jpg
# Renamed: photo363.txt -> yayphoto128.txt
# Renamed: photo377.jpg -> yayphoto129.jpg
# Renamed: photo377.txt -> yayphoto129.txt
# Renamed: photo411.jpg -> yayphoto130.jpg
# Renamed: photo411.txt -> yayphoto130.txt
# Renamed: photo439.jpg -> yayphoto131.jpg
# Renamed: photo439.txt -> yayphoto131.txt
# Renamed: photo388.jpg -> yayphoto132.jpg
# Renamed: photo388.txt -> yayphoto132.txt
# Renamed: photo8.jpg -> yayphoto133.jpg
# Renamed: photo8.txt -> yayphoto133.txt
# Renamed: photo161.jpg -> yayphoto134.jpg
# Renamed: photo161.txt -> yayphoto134.txt
# Renamed: photo607.jpg -> yayphoto135.jpg
# Renamed: photo607.txt -> yayphoto135.txt
# Renamed: photo613.jpg -> yayphoto136.jpg
# Renamed: photo613.txt -> yayphoto136.txt
# Renamed: photo175.jpg -> yayphoto137.jpg
# Renamed: photo175.txt -> yayphoto137.txt
# Renamed: photo149.jpg -> yayphoto138.jpg
# Renamed: photo149.txt -> yayphoto138.txt
# Renamed: photo148.jpg -> yayphoto139.jpg
# Renamed: photo148.txt -> yayphoto139.txt
# Renamed: photo612.jpg -> yayphoto140.jpg
# Renamed: photo612.txt -> yayphoto140.txt
# Renamed: photo174.jpg -> yayphoto141.jpg
# Renamed: photo174.txt -> yayphoto141.txt
# Renamed: photo160.jpg -> yayphoto142.jpg
# Renamed: photo160.txt -> yayphoto142.txt
# Renamed: photo606.jpg -> yayphoto143.jpg
# Renamed: photo606.txt -> yayphoto143.txt
# Renamed: photo9.jpg -> yayphoto144.jpg
# Renamed: photo9.txt -> yayphoto144.txt
# Renamed: photo389.jpg -> yayphoto145.jpg
# Renamed: photo389.txt -> yayphoto145.txt
# Renamed: photo438.jpg -> yayphoto146.jpg
# Renamed: photo438.txt -> yayphoto146.txt
# Renamed: photo376.jpg -> yayphoto147.jpg
# Renamed: photo376.txt -> yayphoto147.txt
# Renamed: photo410.jpg -> yayphoto148.jpg
# Renamed: photo410.txt -> yayphoto148.txt
# Renamed: photo404.jpg -> yayphoto149.jpg
# Renamed: photo404.txt -> yayphoto149.txt
# Renamed: photo362.jpg -> yayphoto150.jpg
# Renamed: photo362.txt -> yayphoto150.txt
# Renamed: photo58.jpg -> yayphoto151.jpg
# Renamed: photo58.txt -> yayphoto151.txt
# Renamed: photo70.jpg -> yayphoto152.jpg
# Renamed: photo70.txt -> yayphoto152.txt
# Renamed: photo64.jpg -> yayphoto153.jpg
# Renamed: photo64.txt -> yayphoto153.txt
# Renamed: photo558.jpg -> yayphoto154.jpg
# Renamed: photo558.txt -> yayphoto154.txt
# Renamed: photo202.jpg -> yayphoto155.jpg
# Renamed: photo202.txt -> yayphoto155.txt
# Renamed: photo564.jpg -> yayphoto156.jpg
# Renamed: photo564.txt -> yayphoto156.txt
# Renamed: photo570.jpg -> yayphoto157.jpg
# Renamed: photo570.txt -> yayphoto157.txt
# Renamed: photo216.jpg -> yayphoto158.jpg
# Renamed: photo216.txt -> yayphoto158.txt
# Renamed: photo259.jpg -> yayphoto159.jpg
# Renamed: photo259.txt -> yayphoto159.txt
# Renamed: photo517.jpg -> yayphoto160.jpg
# Renamed: photo517.txt -> yayphoto160.txt
# Renamed: photo271.jpg -> yayphoto161.jpg
# Renamed: photo271.txt -> yayphoto161.txt
# Renamed: photo265.jpg -> yayphoto162.jpg
# Renamed: photo265.txt -> yayphoto162.txt
# Renamed: photo503.jpg -> yayphoto163.jpg
# Renamed: photo503.txt -> yayphoto163.txt
# Renamed: photo17.jpg -> yayphoto164.jpg
# Renamed: photo17.txt -> yayphoto164.txt
# Renamed: photo339.jpg -> yayphoto165.jpg
# Renamed: photo339.txt -> yayphoto165.txt
# Renamed: photo463.jpg -> yayphoto166.jpg
# Renamed: photo463.txt -> yayphoto166.txt
# Renamed: photo305.jpg -> yayphoto167.jpg
# Renamed: photo305.txt -> yayphoto167.txt
# Renamed: photo311.jpg -> yayphoto168.jpg
# Renamed: photo311.txt -> yayphoto168.txt
# Renamed: photo477.jpg -> yayphoto169.jpg
# Renamed: photo477.txt -> yayphoto169.txt
# Renamed: photo488.jpg -> yayphoto170.jpg
# Renamed: photo488.txt -> yayphoto170.txt
# Renamed: photo649.jpg -> yayphoto171.jpg
# Renamed: photo649.txt -> yayphoto171.txt
# Renamed: photo107.jpg -> yayphoto172.jpg
# Renamed: photo107.txt -> yayphoto172.txt
# Renamed: photo661.jpg -> yayphoto173.jpg
# Renamed: photo661.txt -> yayphoto173.txt
# Renamed: photo675.jpg -> yayphoto174.jpg
# Renamed: photo675.txt -> yayphoto174.txt
# Renamed: photo113.jpg -> yayphoto175.jpg
# Renamed: photo113.txt -> yayphoto175.txt
# Renamed: photo674.jpg -> yayphoto176.jpg
# Renamed: photo674.txt -> yayphoto176.txt
# Renamed: photo112.jpg -> yayphoto177.jpg
# Renamed: photo112.txt -> yayphoto177.txt
# Renamed: photo106.jpg -> yayphoto178.jpg
# Renamed: photo106.txt -> yayphoto178.txt
# Renamed: photo660.jpg -> yayphoto179.jpg
# Renamed: photo660.txt -> yayphoto179.txt
# Renamed: photo648.jpg -> yayphoto180.jpg
# Renamed: photo648.txt -> yayphoto180.txt
# Renamed: photo489.jpg -> yayphoto181.jpg
# Renamed: photo489.txt -> yayphoto181.txt
# Renamed: photo310.jpg -> yayphoto182.jpg
# Renamed: photo310.txt -> yayphoto182.txt
# Renamed: photo476.jpg -> yayphoto183.jpg
# Renamed: photo476.txt -> yayphoto183.txt
# Renamed: photo462.jpg -> yayphoto184.jpg
# Renamed: photo462.txt -> yayphoto184.txt
# Renamed: photo304.jpg -> yayphoto185.jpg
# Renamed: photo304.txt -> yayphoto185.txt
# Renamed: photo338.jpg -> yayphoto186.jpg
# Renamed: photo338.txt -> yayphoto186.txt
# Renamed: photo16.jpg -> yayphoto187.jpg
# Renamed: photo16.txt -> yayphoto187.txt
# Renamed: photo264.jpg -> yayphoto188.jpg
# Renamed: photo264.txt -> yayphoto188.txt
# Renamed: photo502.jpg -> yayphoto189.jpg
# Renamed: photo502.txt -> yayphoto189.txt
# Renamed: photo516.jpg -> yayphoto190.jpg
# Renamed: photo516.txt -> yayphoto190.txt
# Renamed: photo270.jpg -> yayphoto191.jpg
# Renamed: photo270.txt -> yayphoto191.txt
# Renamed: photo258.jpg -> yayphoto192.jpg
# Renamed: photo258.txt -> yayphoto192.txt
# Renamed: photo528.jpg -> yayphoto193.jpg
# Renamed: photo528.txt -> yayphoto193.txt
# Renamed: photo500.jpg -> yayphoto194.jpg
# Renamed: photo500.txt -> yayphoto194.txt
# Renamed: photo266.jpg -> yayphoto195.jpg
# Renamed: photo266.txt -> yayphoto195.txt
# Renamed: photo272.jpg -> yayphoto196.jpg
# Renamed: photo272.txt -> yayphoto196.txt
# Renamed: photo514.jpg -> yayphoto197.jpg
# Renamed: photo514.txt -> yayphoto197.txt
# Renamed: photo28.jpg -> yayphoto198.jpg
# Renamed: photo28.txt -> yayphoto198.txt
# Renamed: photo299.jpg -> yayphoto199.jpg
# Renamed: photo299.txt -> yayphoto199.txt
# Renamed: photo14.jpg -> yayphoto200.jpg
# Renamed: photo14.txt -> yayphoto200.txt
# Renamed: photo448.jpg -> yayphoto201.jpg
# Renamed: photo448.txt -> yayphoto201.txt
# Renamed: photo474.jpg -> yayphoto202.jpg
# Renamed: photo474.txt -> yayphoto202.txt
# Renamed: photo312.jpg -> yayphoto203.jpg
# Renamed: photo312.txt -> yayphoto203.txt
# Renamed: photo306.jpg -> yayphoto204.jpg
# Renamed: photo306.txt -> yayphoto204.txt
# Renamed: photo460.jpg -> yayphoto205.jpg
# Renamed: photo460.txt -> yayphoto205.txt
# Renamed: photo138.jpg -> yayphoto206.jpg
# Renamed: photo138.txt -> yayphoto206.txt
# Renamed: photo110.jpg -> yayphoto207.jpg
# Renamed: photo110.txt -> yayphoto207.txt
# Renamed: photo676.jpg -> yayphoto208.jpg
# Renamed: photo676.txt -> yayphoto208.txt
# Renamed: photo662.jpg -> yayphoto209.jpg
# Renamed: photo662.txt -> yayphoto209.txt
# Renamed: photo104.jpg -> yayphoto210.jpg
# Renamed: photo104.txt -> yayphoto210.txt
# Renamed: photo689.jpg -> yayphoto211.jpg
# Renamed: photo689.txt -> yayphoto211.txt
# Renamed: photo688.jpg -> yayphoto212.jpg
# Renamed: photo688.txt -> yayphoto212.txt
# Renamed: photo663.jpg -> yayphoto213.jpg
# Renamed: photo663.txt -> yayphoto213.txt
# Renamed: photo105.jpg -> yayphoto214.jpg
# Renamed: photo105.txt -> yayphoto214.txt
# Renamed: photo111.jpg -> yayphoto215.jpg
# Renamed: photo111.txt -> yayphoto215.txt
# Renamed: photo677.jpg -> yayphoto216.jpg
# Renamed: photo677.txt -> yayphoto216.txt
# Renamed: photo139.jpg -> yayphoto217.jpg
# Renamed: photo139.txt -> yayphoto217.txt
# Renamed: photo307.jpg -> yayphoto218.jpg
# Renamed: photo307.txt -> yayphoto218.txt
# Renamed: photo461.jpg -> yayphoto219.jpg
# Renamed: photo461.txt -> yayphoto219.txt
# Renamed: photo475.jpg -> yayphoto220.jpg
# Renamed: photo475.txt -> yayphoto220.txt
# Renamed: photo313.jpg -> yayphoto221.jpg
# Renamed: photo313.txt -> yayphoto221.txt
# Renamed: photo449.jpg -> yayphoto222.jpg
# Renamed: photo449.txt -> yayphoto222.txt
# Renamed: photo15.jpg -> yayphoto223.jpg
# Renamed: photo15.txt -> yayphoto223.txt
# Renamed: photo29.jpg -> yayphoto224.jpg
# Renamed: photo29.txt -> yayphoto224.txt
# Renamed: photo298.jpg -> yayphoto225.jpg
# Renamed: photo298.txt -> yayphoto225.txt
# Renamed: photo273.jpg -> yayphoto226.jpg
# Renamed: photo273.txt -> yayphoto226.txt
# Renamed: photo515.jpg -> yayphoto227.jpg
# Renamed: photo515.txt -> yayphoto227.txt
# Renamed: photo501.jpg -> yayphoto228.jpg
# Renamed: photo501.txt -> yayphoto228.txt
# Renamed: photo267.jpg -> yayphoto229.jpg
# Renamed: photo267.txt -> yayphoto229.txt
# Renamed: photo529.jpg -> yayphoto230.jpg
# Renamed: photo529.txt -> yayphoto230.txt
# Renamed: photo263.jpg -> yayphoto231.jpg
# Renamed: photo263.txt -> yayphoto231.txt
# Renamed: photo505.jpg -> yayphoto232.jpg
# Renamed: photo505.txt -> yayphoto232.txt
# Renamed: photo511.jpg -> yayphoto233.jpg
# Renamed: photo511.txt -> yayphoto233.txt
# Renamed: photo277.jpg -> yayphoto234.jpg
# Renamed: photo277.txt -> yayphoto234.txt
# Renamed: photo539.jpg -> yayphoto235.jpg
# Renamed: photo539.txt -> yayphoto235.txt
# Renamed: photo11.jpg -> yayphoto236.jpg
# Renamed: photo11.txt -> yayphoto236.txt
# Renamed: photo39.jpg -> yayphoto237.jpg
# Renamed: photo39.txt -> yayphoto237.txt
# Renamed: photo288.jpg -> yayphoto238.jpg
# Renamed: photo288.txt -> yayphoto238.txt
# Renamed: photo317.jpg -> yayphoto239.jpg
# Renamed: photo317.txt -> yayphoto239.txt
# Renamed: photo471.jpg -> yayphoto240.jpg
# Renamed: photo471.txt -> yayphoto240.txt
# Renamed: photo465.jpg -> yayphoto241.jpg
# Renamed: photo465.txt -> yayphoto241.txt
# Renamed: photo303.jpg -> yayphoto242.jpg
# Renamed: photo303.txt -> yayphoto242.txt
# Renamed: photo459.jpg -> yayphoto243.jpg
# Renamed: photo459.txt -> yayphoto243.txt
# Renamed: photo673.jpg -> yayphoto244.jpg
# Renamed: photo673.txt -> yayphoto244.txt
# Renamed: photo115.jpg -> yayphoto245.jpg
# Renamed: photo115.txt -> yayphoto245.txt
# Renamed: photo101.jpg -> yayphoto246.jpg
# Renamed: photo101.txt -> yayphoto246.txt
# Renamed: photo667.jpg -> yayphoto247.jpg
# Renamed: photo667.txt -> yayphoto247.txt
# Renamed: photo129.jpg -> yayphoto248.jpg
# Renamed: photo129.txt -> yayphoto248.txt
# Renamed: photo128.jpg -> yayphoto249.jpg
# Renamed: photo128.txt -> yayphoto249.txt
# Renamed: photo100.jpg -> yayphoto250.jpg
# Renamed: photo100.txt -> yayphoto250.txt
# Renamed: photo666.jpg -> yayphoto251.jpg
# Renamed: photo666.txt -> yayphoto251.txt
# Renamed: photo672.jpg -> yayphoto252.jpg
# Renamed: photo672.txt -> yayphoto252.txt
# Renamed: photo114.jpg -> yayphoto253.jpg
# Renamed: photo114.txt -> yayphoto253.txt
# Renamed: photo458.jpg -> yayphoto254.jpg
# Renamed: photo458.txt -> yayphoto254.txt
# Renamed: photo464.jpg -> yayphoto255.jpg
# Renamed: photo464.txt -> yayphoto255.txt
# Renamed: photo302.jpg -> yayphoto256.jpg
# Renamed: photo302.txt -> yayphoto256.txt
# Renamed: photo316.jpg -> yayphoto257.jpg
# Renamed: photo316.txt -> yayphoto257.txt
# Renamed: photo470.jpg -> yayphoto258.jpg
# Renamed: photo470.txt -> yayphoto258.txt
# Renamed: photo38.jpg -> yayphoto259.jpg
# Renamed: photo38.txt -> yayphoto259.txt
# Renamed: photo289.jpg -> yayphoto260.jpg
# Renamed: photo289.txt -> yayphoto260.txt
# Renamed: photo10.jpg -> yayphoto261.jpg
# Renamed: photo10.txt -> yayphoto261.txt
# Renamed: photo538.jpg -> yayphoto262.jpg
# Renamed: photo538.txt -> yayphoto262.txt
# Renamed: photo510.jpg -> yayphoto263.jpg
# Renamed: photo510.txt -> yayphoto263.txt
# Renamed: photo276.jpg -> yayphoto264.jpg
# Renamed: photo276.txt -> yayphoto264.txt
# Renamed: photo262.jpg -> yayphoto265.jpg
# Renamed: photo262.txt -> yayphoto265.txt
# Renamed: photo504.jpg -> yayphoto266.jpg
# Renamed: photo504.txt -> yayphoto266.txt
# Renamed: photo274.jpg -> yayphoto267.jpg
# Renamed: photo274.txt -> yayphoto267.txt
# Renamed: photo512.jpg -> yayphoto268.jpg
# Renamed: photo512.txt -> yayphoto268.txt
# Renamed: photo506.jpg -> yayphoto269.jpg
# Renamed: photo506.txt -> yayphoto269.txt
# Renamed: photo260.jpg -> yayphoto270.jpg
# Renamed: photo260.txt -> yayphoto270.txt
# Renamed: photo248.jpg -> yayphoto271.jpg
# Renamed: photo248.txt -> yayphoto271.txt
# Renamed: photo12.jpg -> yayphoto272.jpg
# Renamed: photo12.txt -> yayphoto272.txt
# Renamed: photo300.jpg -> yayphoto273.jpg
# Renamed: photo300.txt -> yayphoto273.txt
# Renamed: photo466.jpg -> yayphoto274.jpg
# Renamed: photo466.txt -> yayphoto274.txt
# Renamed: photo472.jpg -> yayphoto275.jpg
# Renamed: photo472.txt -> yayphoto275.txt
# Renamed: photo314.jpg -> yayphoto276.jpg
# Renamed: photo314.txt -> yayphoto276.txt
# Renamed: photo328.jpg -> yayphoto277.jpg
# Renamed: photo328.txt -> yayphoto277.txt
# Renamed: photo499.jpg -> yayphoto278.jpg
# Renamed: photo499.txt -> yayphoto278.txt
# Renamed: photo664.jpg -> yayphoto279.jpg
# Renamed: photo664.txt -> yayphoto279.txt
# Renamed: photo102.jpg -> yayphoto280.jpg
# Renamed: photo102.txt -> yayphoto280.txt
# Renamed: photo116.jpg -> yayphoto281.jpg
# Renamed: photo116.txt -> yayphoto281.txt
# Renamed: photo670.jpg -> yayphoto282.jpg
# Renamed: photo670.txt -> yayphoto282.txt
# Renamed: photo658.jpg -> yayphoto283.jpg
# Renamed: photo658.txt -> yayphoto283.txt
# Renamed: photo659.jpg -> yayphoto284.jpg
# Renamed: photo659.txt -> yayphoto284.txt
# Renamed: photo117.jpg -> yayphoto285.jpg
# Renamed: photo117.txt -> yayphoto285.txt
# Renamed: photo671.jpg -> yayphoto286.jpg
# Renamed: photo671.txt -> yayphoto286.txt
# Renamed: photo665.jpg -> yayphoto287.jpg
# Renamed: photo665.txt -> yayphoto287.txt
# Renamed: photo103.jpg -> yayphoto288.jpg
# Renamed: photo103.txt -> yayphoto288.txt
# Renamed: photo498.jpg -> yayphoto289.jpg
# Renamed: photo498.txt -> yayphoto289.txt
# Renamed: photo329.jpg -> yayphoto290.jpg
# Renamed: photo329.txt -> yayphoto290.txt
# Renamed: photo473.jpg -> yayphoto291.jpg
# Renamed: photo473.txt -> yayphoto291.txt
# Renamed: photo315.jpg -> yayphoto292.jpg
# Renamed: photo315.txt -> yayphoto292.txt
# Renamed: photo301.jpg -> yayphoto293.jpg
# Renamed: photo301.txt -> yayphoto293.txt
# Renamed: photo467.jpg -> yayphoto294.jpg
# Renamed: photo467.txt -> yayphoto294.txt
# Renamed: photo13.jpg -> yayphoto295.jpg
# Renamed: photo13.txt -> yayphoto295.txt
# Renamed: photo249.jpg -> yayphoto296.jpg
# Renamed: photo249.txt -> yayphoto296.txt
# Renamed: photo507.jpg -> yayphoto297.jpg
# Renamed: photo507.txt -> yayphoto297.txt
# Renamed: photo261.jpg -> yayphoto298.jpg
# Renamed: photo261.txt -> yayphoto298.txt
# Renamed: photo275.jpg -> yayphoto299.jpg
# Renamed: photo275.txt -> yayphoto299.txt
# Renamed: photo513.jpg -> yayphoto300.jpg
# Renamed: photo513.txt -> yayphoto300.txt
# Renamed: photo278.jpg -> yayphoto301.jpg
# Renamed: photo278.txt -> yayphoto301.txt
# Renamed: photo536.jpg -> yayphoto302.jpg
# Renamed: photo536.txt -> yayphoto302.txt
# Renamed: photo250.jpg -> yayphoto303.jpg
# Renamed: photo250.txt -> yayphoto303.txt
# Renamed: photo244.jpg -> yayphoto304.jpg
# Renamed: photo244.txt -> yayphoto304.txt
# Renamed: photo522.jpg -> yayphoto305.jpg
# Renamed: photo522.txt -> yayphoto305.txt
# Renamed: photo22.jpg -> yayphoto306.jpg
# Renamed: photo22.txt -> yayphoto306.txt
# Renamed: photo293.jpg -> yayphoto307.jpg
# Renamed: photo293.txt -> yayphoto307.txt
# Renamed: photo287.jpg -> yayphoto308.jpg
# Renamed: photo287.txt -> yayphoto308.txt
# Renamed: photo36.jpg -> yayphoto309.jpg
# Renamed: photo36.txt -> yayphoto309.txt
# Renamed: photo318.jpg -> yayphoto310.jpg
# Renamed: photo318.txt -> yayphoto310.txt
# Renamed: photo442.jpg -> yayphoto311.jpg
# Renamed: photo442.txt -> yayphoto311.txt
# Renamed: photo324.jpg -> yayphoto312.jpg
# Renamed: photo324.txt -> yayphoto312.txt
# Renamed: photo330.jpg -> yayphoto313.jpg
# Renamed: photo330.txt -> yayphoto313.txt
# Renamed: photo456.jpg -> yayphoto314.jpg
# Renamed: photo456.txt -> yayphoto314.txt
# Renamed: photo481.jpg -> yayphoto315.jpg
# Renamed: photo481.txt -> yayphoto315.txt
# Renamed: photo495.jpg -> yayphoto316.jpg
# Renamed: photo495.txt -> yayphoto316.txt
# Renamed: photo668.jpg -> yayphoto317.jpg
# Renamed: photo668.txt -> yayphoto317.txt
# Renamed: photo126.jpg -> yayphoto318.jpg
# Renamed: photo126.txt -> yayphoto318.txt
# Renamed: photo640.jpg -> yayphoto319.jpg
# Renamed: photo640.txt -> yayphoto319.txt
# Renamed: photo654.jpg -> yayphoto320.jpg
# Renamed: photo654.txt -> yayphoto320.txt
# Renamed: photo132.jpg -> yayphoto321.jpg
# Renamed: photo132.txt -> yayphoto321.txt
# Renamed: photo683.jpg -> yayphoto322.jpg
# Renamed: photo683.txt -> yayphoto322.txt
# Renamed: photo696.jpg -> yayphoto323.jpg
# Renamed: photo696.txt -> yayphoto323.txt
# Renamed: photo682.jpg -> yayphoto324.jpg
# Renamed: photo682.txt -> yayphoto324.txt
# Renamed: photo655.jpg -> yayphoto325.jpg
# Renamed: photo655.txt -> yayphoto325.txt
# Renamed: photo133.jpg -> yayphoto326.jpg
# Renamed: photo133.txt -> yayphoto326.txt
# Renamed: photo127.jpg -> yayphoto327.jpg
# Renamed: photo127.txt -> yayphoto327.txt
# Renamed: photo641.jpg -> yayphoto328.jpg
# Renamed: photo641.txt -> yayphoto328.txt
# Renamed: photo669.jpg -> yayphoto329.jpg
# Renamed: photo669.txt -> yayphoto329.txt
# Renamed: photo494.jpg -> yayphoto330.jpg
# Renamed: photo494.txt -> yayphoto330.txt
# Renamed: photo480.jpg -> yayphoto331.jpg
# Renamed: photo480.txt -> yayphoto331.txt
# Renamed: photo331.jpg -> yayphoto332.jpg
# Renamed: photo331.txt -> yayphoto332.txt
# Renamed: photo457.jpg -> yayphoto333.jpg
# Renamed: photo457.txt -> yayphoto333.txt
# Renamed: photo443.jpg -> yayphoto334.jpg
# Renamed: photo443.txt -> yayphoto334.txt
# Renamed: photo325.jpg -> yayphoto335.jpg
# Renamed: photo325.txt -> yayphoto335.txt
# Renamed: photo319.jpg -> yayphoto336.jpg
# Renamed: photo319.txt -> yayphoto336.txt
# Renamed: photo286.jpg -> yayphoto337.jpg
# Renamed: photo286.txt -> yayphoto337.txt
# Renamed: photo37.jpg -> yayphoto338.jpg
# Renamed: photo37.txt -> yayphoto338.txt
# Renamed: photo23.jpg -> yayphoto339.jpg
# Renamed: photo23.txt -> yayphoto339.txt
# Renamed: photo292.jpg -> yayphoto340.jpg
# Renamed: photo292.txt -> yayphoto340.txt
# Renamed: photo245.jpg -> yayphoto341.jpg
# Renamed: photo245.txt -> yayphoto341.txt
# Renamed: photo523.jpg -> yayphoto342.jpg
# Renamed: photo523.txt -> yayphoto342.txt
# Renamed: photo537.jpg -> yayphoto343.jpg
# Renamed: photo537.txt -> yayphoto343.txt
# Renamed: photo251.jpg -> yayphoto344.jpg
# Renamed: photo251.txt -> yayphoto344.txt
# Renamed: photo279.jpg -> yayphoto345.jpg
# Renamed: photo279.txt -> yayphoto345.txt
# Renamed: photo509.jpg -> yayphoto346.jpg
# Renamed: photo509.txt -> yayphoto346.txt
# Renamed: photo521.jpg -> yayphoto347.jpg
# Renamed: photo521.txt -> yayphoto347.txt
# Renamed: photo247.jpg -> yayphoto348.jpg
# Renamed: photo247.txt -> yayphoto348.txt
# Renamed: photo253.jpg -> yayphoto349.jpg
# Renamed: photo253.txt -> yayphoto349.txt
# Renamed: photo535.jpg -> yayphoto350.jpg
# Renamed: photo535.txt -> yayphoto350.txt
# Renamed: photo35.jpg -> yayphoto351.jpg
# Renamed: photo35.txt -> yayphoto351.txt
# Renamed: photo284.jpg -> yayphoto352.jpg
# Renamed: photo284.txt -> yayphoto352.txt
# Renamed: photo290.jpg -> yayphoto353.jpg
# Renamed: photo290.txt -> yayphoto353.txt
# Renamed: photo21.jpg -> yayphoto354.jpg
# Renamed: photo21.txt -> yayphoto354.txt
# Renamed: photo469.jpg -> yayphoto355.jpg
# Renamed: photo469.txt -> yayphoto355.txt
# Renamed: photo455.jpg -> yayphoto356.jpg
# Renamed: photo455.txt -> yayphoto356.txt
# Renamed: photo333.jpg -> yayphoto357.jpg
# Renamed: photo333.txt -> yayphoto357.txt
# Renamed: photo327.jpg -> yayphoto358.jpg
# Renamed: photo327.txt -> yayphoto358.txt
# Renamed: photo441.jpg -> yayphoto359.jpg
# Renamed: photo441.txt -> yayphoto359.txt
# Renamed: photo496.jpg -> yayphoto360.jpg
# Renamed: photo496.txt -> yayphoto360.txt
# Renamed: photo482.jpg -> yayphoto361.jpg
# Renamed: photo482.txt -> yayphoto361.txt
# Renamed: photo119.jpg -> yayphoto362.jpg
# Renamed: photo119.txt -> yayphoto362.txt
# Renamed: photo131.jpg -> yayphoto363.jpg
# Renamed: photo131.txt -> yayphoto363.txt
# Renamed: photo657.jpg -> yayphoto364.jpg
# Renamed: photo657.txt -> yayphoto364.txt
# Renamed: photo643.jpg -> yayphoto365.jpg
# Renamed: photo643.txt -> yayphoto365.txt
# Renamed: photo125.jpg -> yayphoto366.jpg
# Renamed: photo125.txt -> yayphoto366.txt
# Renamed: photo694.jpg -> yayphoto367.jpg
# Renamed: photo694.txt -> yayphoto367.txt
# Renamed: photo680.jpg -> yayphoto368.jpg
# Renamed: photo680.txt -> yayphoto368.txt
# Renamed: photo681.jpg -> yayphoto369.jpg
# Renamed: photo681.txt -> yayphoto369.txt
# Renamed: photo695.jpg -> yayphoto370.jpg
# Renamed: photo695.txt -> yayphoto370.txt
# Renamed: photo642.jpg -> yayphoto371.jpg
# Renamed: photo642.txt -> yayphoto371.txt
# Renamed: photo124.jpg -> yayphoto372.jpg
# Renamed: photo124.txt -> yayphoto372.txt
# Renamed: photo130.jpg -> yayphoto373.jpg
# Renamed: photo130.txt -> yayphoto373.txt
# Renamed: photo656.jpg -> yayphoto374.jpg
# Renamed: photo656.txt -> yayphoto374.txt
# Renamed: photo118.jpg -> yayphoto375.jpg
# Renamed: photo118.txt -> yayphoto375.txt
# Renamed: photo483.jpg -> yayphoto376.jpg
# Renamed: photo483.txt -> yayphoto376.txt
# Renamed: photo497.jpg -> yayphoto377.jpg
# Renamed: photo497.txt -> yayphoto377.txt
# Renamed: photo326.jpg -> yayphoto378.jpg
# Renamed: photo326.txt -> yayphoto378.txt
# Renamed: photo440.jpg -> yayphoto379.jpg
# Renamed: photo440.txt -> yayphoto379.txt
# Renamed: photo454.jpg -> yayphoto380.jpg
# Renamed: photo454.txt -> yayphoto380.txt
# Renamed: photo332.jpg -> yayphoto381.jpg
# Renamed: photo332.txt -> yayphoto381.txt
# Renamed: photo468.jpg -> yayphoto382.jpg
# Renamed: photo468.txt -> yayphoto382.txt
# Renamed: photo291.jpg -> yayphoto383.jpg
# Renamed: photo291.txt -> yayphoto383.txt
# Renamed: photo20.jpg -> yayphoto384.jpg
# Renamed: photo20.txt -> yayphoto384.txt
# Renamed: photo34.jpg -> yayphoto385.jpg
# Renamed: photo34.txt -> yayphoto385.txt
# Renamed: photo285.jpg -> yayphoto386.jpg
# Renamed: photo285.txt -> yayphoto386.txt
# Renamed: photo252.jpg -> yayphoto387.jpg
# Renamed: photo252.txt -> yayphoto387.txt
# Renamed: photo534.jpg -> yayphoto388.jpg
# Renamed: photo534.txt -> yayphoto388.txt
# Renamed: photo520.jpg -> yayphoto389.jpg
# Renamed: photo520.txt -> yayphoto389.txt
# Renamed: photo246.jpg -> yayphoto390.jpg
# Renamed: photo246.txt -> yayphoto390.txt
# Renamed: photo508.jpg -> yayphoto391.jpg
# Renamed: photo508.txt -> yayphoto391.txt
# Renamed: photo242.jpg -> yayphoto392.jpg
# Renamed: photo242.txt -> yayphoto392.txt
# Renamed: photo524.jpg -> yayphoto393.jpg
# Renamed: photo524.txt -> yayphoto393.txt
# Renamed: photo530.jpg -> yayphoto394.jpg
# Renamed: photo530.txt -> yayphoto394.txt
# Renamed: photo256.jpg -> yayphoto395.jpg
# Renamed: photo256.txt -> yayphoto395.txt
# Renamed: photo518.jpg -> yayphoto396.jpg
# Renamed: photo518.txt -> yayphoto396.txt
# Renamed: photo281.jpg -> yayphoto397.jpg
# Renamed: photo281.txt -> yayphoto397.txt
# Renamed: photo30.jpg -> yayphoto398.jpg
# Renamed: photo30.txt -> yayphoto398.txt
# Renamed: photo24.jpg -> yayphoto399.jpg
# Renamed: photo24.txt -> yayphoto399.txt
# Renamed: photo295.jpg -> yayphoto400.jpg
# Renamed: photo295.txt -> yayphoto400.txt
# Renamed: photo18.jpg -> yayphoto401.jpg
# Renamed: photo18.txt -> yayphoto401.txt
# Renamed: photo336.jpg -> yayphoto402.jpg
# Renamed: photo336.txt -> yayphoto402.txt
# Renamed: photo450.jpg -> yayphoto403.jpg
# Renamed: photo450.txt -> yayphoto403.txt
# Renamed: photo444.jpg -> yayphoto404.jpg
# Renamed: photo444.txt -> yayphoto404.txt
# Renamed: photo322.jpg -> yayphoto405.jpg
# Renamed: photo322.txt -> yayphoto405.txt
# Renamed: photo478.jpg -> yayphoto406.jpg
# Renamed: photo478.txt -> yayphoto406.txt
# Renamed: photo493.jpg -> yayphoto407.jpg
# Renamed: photo493.txt -> yayphoto407.txt
# Renamed: photo487.jpg -> yayphoto408.jpg
# Renamed: photo487.txt -> yayphoto408.txt
# Renamed: photo652.jpg -> yayphoto409.jpg
# Renamed: photo652.txt -> yayphoto409.txt
# Renamed: photo134.jpg -> yayphoto410.jpg
# Renamed: photo134.txt -> yayphoto410.txt
# Renamed: photo120.jpg -> yayphoto411.jpg
# Renamed: photo120.txt -> yayphoto411.txt
# Renamed: photo646.jpg -> yayphoto412.jpg
# Renamed: photo646.txt -> yayphoto412.txt
# Renamed: photo108.jpg -> yayphoto413.jpg
# Renamed: photo108.txt -> yayphoto413.txt
# Renamed: photo691.jpg -> yayphoto414.jpg
# Renamed: photo691.txt -> yayphoto414.txt
# Renamed: photo685.jpg -> yayphoto415.jpg
# Renamed: photo685.txt -> yayphoto415.txt
# Renamed: photo684.jpg -> yayphoto416.jpg
# Renamed: photo684.txt -> yayphoto416.txt
# Renamed: photo690.jpg -> yayphoto417.jpg
# Renamed: photo690.txt -> yayphoto417.txt
# Renamed: photo109.jpg -> yayphoto418.jpg
# Renamed: photo109.txt -> yayphoto418.txt
# Renamed: photo121.jpg -> yayphoto419.jpg
# Renamed: photo121.txt -> yayphoto419.txt
# Renamed: photo647.jpg -> yayphoto420.jpg
# Renamed: photo647.txt -> yayphoto420.txt
# Renamed: photo653.jpg -> yayphoto421.jpg
# Renamed: photo653.txt -> yayphoto421.txt
# Renamed: photo135.jpg -> yayphoto422.jpg
# Renamed: photo135.txt -> yayphoto422.txt
# Renamed: photo486.jpg -> yayphoto423.jpg
# Renamed: photo486.txt -> yayphoto423.txt
# Renamed: photo492.jpg -> yayphoto424.jpg
# Renamed: photo492.txt -> yayphoto424.txt
# Renamed: photo479.jpg -> yayphoto425.jpg
# Renamed: photo479.txt -> yayphoto425.txt
# Renamed: photo445.jpg -> yayphoto426.jpg
# Renamed: photo445.txt -> yayphoto426.txt
# Renamed: photo323.jpg -> yayphoto427.jpg
# Renamed: photo323.txt -> yayphoto427.txt
# Renamed: photo337.jpg -> yayphoto428.jpg
# Renamed: photo337.txt -> yayphoto428.txt
# Renamed: photo451.jpg -> yayphoto429.jpg
# Renamed: photo451.txt -> yayphoto429.txt
# Renamed: photo19.jpg -> yayphoto430.jpg
# Renamed: photo19.txt -> yayphoto430.txt
# Renamed: photo25.jpg -> yayphoto431.jpg
# Renamed: photo25.txt -> yayphoto431.txt
# Renamed: photo294.jpg -> yayphoto432.jpg
# Renamed: photo294.txt -> yayphoto432.txt
# Renamed: photo280.jpg -> yayphoto433.jpg
# Renamed: photo280.txt -> yayphoto433.txt
# Renamed: photo31.jpg -> yayphoto434.jpg
# Renamed: photo31.txt -> yayphoto434.txt
# Renamed: photo519.jpg -> yayphoto435.jpg
# Renamed: photo519.txt -> yayphoto435.txt
# Renamed: photo531.jpg -> yayphoto436.jpg
# Renamed: photo531.txt -> yayphoto436.txt
# Renamed: photo257.jpg -> yayphoto437.jpg
# Renamed: photo257.txt -> yayphoto437.txt
# Renamed: photo243.jpg -> yayphoto438.jpg
# Renamed: photo243.txt -> yayphoto438.txt
# Renamed: photo525.jpg -> yayphoto439.jpg
# Renamed: photo525.txt -> yayphoto439.txt
# Renamed: photo255.jpg -> yayphoto440.jpg
# Renamed: photo255.txt -> yayphoto440.txt
# Renamed: photo533.jpg -> yayphoto441.jpg
# Renamed: photo533.txt -> yayphoto441.txt
# Renamed: photo527.jpg -> yayphoto442.jpg
# Renamed: photo527.txt -> yayphoto442.txt
# Renamed: photo241.jpg -> yayphoto443.jpg
# Renamed: photo241.txt -> yayphoto443.txt
# Renamed: photo269.jpg -> yayphoto444.jpg
# Renamed: photo269.txt -> yayphoto444.txt
# Renamed: photo296.jpg -> yayphoto445.jpg
# Renamed: photo296.txt -> yayphoto445.txt
# Renamed: photo27.jpg -> yayphoto446.jpg
# Renamed: photo27.txt -> yayphoto446.txt
# Renamed: photo33.jpg -> yayphoto447.jpg
# Renamed: photo33.txt -> yayphoto447.txt
# Renamed: photo282.jpg -> yayphoto448.jpg
# Renamed: photo282.txt -> yayphoto448.txt
# Renamed: photo321.jpg -> yayphoto449.jpg
# Renamed: photo321.txt -> yayphoto449.txt
# Renamed: photo447.jpg -> yayphoto450.jpg
# Renamed: photo447.txt -> yayphoto450.txt
# Renamed: photo453.jpg -> yayphoto451.jpg
# Renamed: photo453.txt -> yayphoto451.txt
# Renamed: photo335.jpg -> yayphoto452.jpg
# Renamed: photo335.txt -> yayphoto452.txt
# Renamed: photo309.jpg -> yayphoto453.jpg
# Renamed: photo309.txt -> yayphoto453.txt
# Renamed: photo484.jpg -> yayphoto454.jpg
# Renamed: photo484.txt -> yayphoto454.txt
# Renamed: photo490.jpg -> yayphoto455.jpg
# Renamed: photo490.txt -> yayphoto455.txt
# Renamed: photo645.jpg -> yayphoto456.jpg
# Renamed: photo645.txt -> yayphoto456.txt
# Renamed: photo123.jpg -> yayphoto457.jpg
# Renamed: photo123.txt -> yayphoto457.txt
# Renamed: photo137.jpg -> yayphoto458.jpg
# Renamed: photo137.txt -> yayphoto458.txt
# Renamed: photo651.jpg -> yayphoto459.jpg
# Renamed: photo651.txt -> yayphoto459.txt
# Renamed: photo679.jpg -> yayphoto460.jpg
# Renamed: photo679.txt -> yayphoto460.txt
# Renamed: photo686.jpg -> yayphoto461.jpg
# Renamed: photo686.txt -> yayphoto461.txt
# Renamed: photo692.jpg -> yayphoto462.jpg
# Renamed: photo692.txt -> yayphoto462.txt
# Renamed: photo693.jpg -> yayphoto463.jpg
# Renamed: photo693.txt -> yayphoto463.txt
# Renamed: photo687.jpg -> yayphoto464.jpg
# Renamed: photo687.txt -> yayphoto464.txt
# Renamed: photo678.jpg -> yayphoto465.jpg
# Renamed: photo678.txt -> yayphoto465.txt
# Renamed: photo136.jpg -> yayphoto466.jpg
# Renamed: photo136.txt -> yayphoto466.txt
# Renamed: photo650.jpg -> yayphoto467.jpg
# Renamed: photo650.txt -> yayphoto467.txt
# Renamed: photo644.jpg -> yayphoto468.jpg
# Renamed: photo644.txt -> yayphoto468.txt
# Renamed: photo122.jpg -> yayphoto469.jpg
# Renamed: photo122.txt -> yayphoto469.txt
# Renamed: photo491.jpg -> yayphoto470.jpg
# Renamed: photo491.txt -> yayphoto470.txt
# Renamed: photo485.jpg -> yayphoto471.jpg
# Renamed: photo485.txt -> yayphoto471.txt
# Renamed: photo308.jpg -> yayphoto472.jpg
# Renamed: photo308.txt -> yayphoto472.txt
# Renamed: photo452.jpg -> yayphoto473.jpg
# Renamed: photo452.txt -> yayphoto473.txt
# Renamed: photo334.jpg -> yayphoto474.jpg
# Renamed: photo334.txt -> yayphoto474.txt
# Renamed: photo320.jpg -> yayphoto475.jpg
# Renamed: photo320.txt -> yayphoto475.txt
# Renamed: photo446.jpg -> yayphoto476.jpg
# Renamed: photo446.txt -> yayphoto476.txt
# Renamed: photo32.jpg -> yayphoto477.jpg
# Renamed: photo32.txt -> yayphoto477.txt
# Renamed: photo283.jpg -> yayphoto478.jpg
# Renamed: photo283.txt -> yayphoto478.txt
# Renamed: photo297.jpg -> yayphoto479.jpg
# Renamed: photo297.txt -> yayphoto479.txt
# Renamed: photo26.jpg -> yayphoto480.jpg
# Renamed: photo26.txt -> yayphoto480.txt
# Renamed: photo268.jpg -> yayphoto481.jpg
# Renamed: photo268.txt -> yayphoto481.txt
# Renamed: photo526.jpg -> yayphoto482.jpg
# Renamed: photo526.txt -> yayphoto482.txt
# Renamed: photo240.jpg -> yayphoto483.jpg
# Renamed: photo240.txt -> yayphoto483.txt
# Renamed: photo254.jpg -> yayphoto484.jpg
# Renamed: photo254.txt -> yayphoto484.txt
# Renamed: photo532.jpg -> yayphoto485.jpg
# Renamed: photo532.txt -> yayphoto485.txt
# Renamed: photo569.jpg -> yayphoto486.jpg
# Renamed: photo569.txt -> yayphoto486.txt
# Renamed: photo233.jpg -> yayphoto487.jpg
# Renamed: photo233.txt -> yayphoto487.txt
# Renamed: photo555.jpg -> yayphoto488.jpg
# Renamed: photo555.txt -> yayphoto488.txt
# Renamed: photo82.jpg -> yayphoto489.jpg
# Renamed: photo82.txt -> yayphoto489.txt
# Renamed: photo541.jpg -> yayphoto490.jpg
# Renamed: photo541.txt -> yayphoto490.txt
# Renamed: photo96.jpg -> yayphoto491.jpg
# Renamed: photo96.txt -> yayphoto491.txt
# Renamed: photo227.jpg -> yayphoto492.jpg
# Renamed: photo227.txt -> yayphoto492.txt
# Renamed: photo69.jpg -> yayphoto493.jpg
# Renamed: photo69.txt -> yayphoto493.txt
# Renamed: photo596.jpg -> yayphoto494.jpg
# Renamed: photo596.txt -> yayphoto494.txt
# Renamed: photo41.jpg -> yayphoto495.jpg
# Renamed: photo41.txt -> yayphoto495.txt
# Renamed: photo582.jpg -> yayphoto496.jpg
# Renamed: photo582.txt -> yayphoto496.txt
# Renamed: photo55.jpg -> yayphoto497.jpg
# Renamed: photo55.txt -> yayphoto497.txt
# Renamed: photo409.jpg -> yayphoto498.jpg
# Renamed: photo409.txt -> yayphoto498.txt
# Renamed: photo347.jpg -> yayphoto499.jpg
# Renamed: photo347.txt -> yayphoto499.txt
# Renamed: photo421.jpg -> yayphoto500.jpg
# Renamed: photo421.txt -> yayphoto500.txt
# Renamed: photo435.jpg -> yayphoto501.jpg
# Renamed: photo435.txt -> yayphoto501.txt
# Renamed: photo353.jpg -> yayphoto502.jpg
# Renamed: photo353.txt -> yayphoto502.txt
# Renamed: photo384.jpg -> yayphoto503.jpg
# Renamed: photo384.txt -> yayphoto503.txt
# Renamed: photo4.jpg -> yayphoto504.jpg
# Renamed: photo4.txt -> yayphoto504.txt
# Renamed: photo390.jpg -> yayphoto505.jpg
# Renamed: photo390.txt -> yayphoto505.txt
# Renamed: photo179.jpg -> yayphoto506.jpg
# Renamed: photo179.txt -> yayphoto506.txt
# Renamed: photo623.jpg -> yayphoto507.jpg
# Renamed: photo623.txt -> yayphoto507.txt
# Renamed: photo145.jpg -> yayphoto508.jpg
# Renamed: photo145.txt -> yayphoto508.txt
# Renamed: photo151.jpg -> yayphoto509.jpg
# Renamed: photo151.txt -> yayphoto509.txt
# Renamed: photo637.jpg -> yayphoto510.jpg
# Renamed: photo637.txt -> yayphoto510.txt
# Renamed: photo186.jpg -> yayphoto511.jpg
# Renamed: photo186.txt -> yayphoto511.txt
# Renamed: photo192.jpg -> yayphoto512.jpg
# Renamed: photo192.txt -> yayphoto512.txt
# Renamed: photo193.jpg -> yayphoto513.jpg
# Renamed: photo193.txt -> yayphoto513.txt
# Renamed: photo187.jpg -> yayphoto514.jpg
# Renamed: photo187.txt -> yayphoto514.txt
# Renamed: photo150.jpg -> yayphoto515.jpg
# Renamed: photo150.txt -> yayphoto515.txt
# Renamed: photo636.jpg -> yayphoto516.jpg
# Renamed: photo636.txt -> yayphoto516.txt
# Renamed: photo622.jpg -> yayphoto517.jpg
# Renamed: photo622.txt -> yayphoto517.txt
# Renamed: photo144.jpg -> yayphoto518.jpg
# Renamed: photo144.txt -> yayphoto518.txt
# Renamed: photo178.jpg -> yayphoto519.jpg
# Renamed: photo178.txt -> yayphoto519.txt
# Renamed: photo391.jpg -> yayphoto520.jpg
# Renamed: photo391.txt -> yayphoto520.txt
# Renamed: photo5.jpg -> yayphoto521.jpg
# Renamed: photo5.txt -> yayphoto521.txt
# Renamed: photo385.jpg -> yayphoto522.jpg
# Renamed: photo385.txt -> yayphoto522.txt
# Renamed: photo434.jpg -> yayphoto523.jpg
# Renamed: photo434.txt -> yayphoto523.txt
# Renamed: photo352.jpg -> yayphoto524.jpg
# Renamed: photo352.txt -> yayphoto524.txt
# Renamed: photo346.jpg -> yayphoto525.jpg
# Renamed: photo346.txt -> yayphoto525.txt
# Renamed: photo420.jpg -> yayphoto526.jpg
# Renamed: photo420.txt -> yayphoto526.txt
# Renamed: photo408.jpg -> yayphoto527.jpg
# Renamed: photo408.txt -> yayphoto527.txt
# Renamed: photo54.jpg -> yayphoto528.jpg
# Renamed: photo54.txt -> yayphoto528.txt
# Renamed: photo583.jpg -> yayphoto529.jpg
# Renamed: photo583.txt -> yayphoto529.txt
# Renamed: photo40.jpg -> yayphoto530.jpg
# Renamed: photo40.txt -> yayphoto530.txt
# Renamed: photo597.jpg -> yayphoto531.jpg
# Renamed: photo597.txt -> yayphoto531.txt
# Renamed: photo68.jpg -> yayphoto532.jpg
# Renamed: photo68.txt -> yayphoto532.txt
# Renamed: photo97.jpg -> yayphoto533.jpg
# Renamed: photo97.txt -> yayphoto533.txt
# Renamed: photo540.jpg -> yayphoto534.jpg
# Renamed: photo540.txt -> yayphoto534.txt
# Renamed: photo226.jpg -> yayphoto535.jpg
# Renamed: photo226.txt -> yayphoto535.txt
# Renamed: photo232.jpg -> yayphoto536.jpg
# Renamed: photo232.txt -> yayphoto536.txt
# Renamed: photo83.jpg -> yayphoto537.jpg
# Renamed: photo83.txt -> yayphoto537.txt
# Renamed: photo554.jpg -> yayphoto538.jpg
# Renamed: photo554.txt -> yayphoto538.txt
# Renamed: photo568.jpg -> yayphoto539.jpg
# Renamed: photo568.txt -> yayphoto539.txt
# Renamed: photo218.jpg -> yayphoto540.jpg
# Renamed: photo218.txt -> yayphoto540.txt
# Renamed: photo224.jpg -> yayphoto541.jpg
# Renamed: photo224.txt -> yayphoto541.txt
# Renamed: photo95.jpg -> yayphoto542.jpg
# Renamed: photo95.txt -> yayphoto542.txt
# Renamed: photo542.jpg -> yayphoto543.jpg
# Renamed: photo542.txt -> yayphoto543.txt
# Renamed: photo81.jpg -> yayphoto544.jpg
# Renamed: photo81.txt -> yayphoto544.txt
# Renamed: photo556.jpg -> yayphoto545.jpg
# Renamed: photo556.txt -> yayphoto545.txt
# Renamed: photo230.jpg -> yayphoto546.jpg
# Renamed: photo230.txt -> yayphoto546.txt
# Renamed: photo56.jpg -> yayphoto547.jpg
# Renamed: photo56.txt -> yayphoto547.txt
# Renamed: photo581.jpg -> yayphoto548.jpg
# Renamed: photo581.txt -> yayphoto548.txt
# Renamed: photo42.jpg -> yayphoto549.jpg
# Renamed: photo42.txt -> yayphoto549.txt
# Renamed: photo595.jpg -> yayphoto550.jpg
# Renamed: photo595.txt -> yayphoto550.txt
# Renamed: photo378.jpg -> yayphoto551.jpg
# Renamed: photo378.txt -> yayphoto551.txt
# Renamed: photo350.jpg -> yayphoto552.jpg
# Renamed: photo350.txt -> yayphoto552.txt
# Renamed: photo436.jpg -> yayphoto553.jpg
# Renamed: photo436.txt -> yayphoto553.txt
# Renamed: photo422.jpg -> yayphoto554.jpg
# Renamed: photo422.txt -> yayphoto554.txt
# Renamed: photo344.jpg -> yayphoto555.jpg
# Renamed: photo344.txt -> yayphoto555.txt
# Renamed: photo393.jpg -> yayphoto556.jpg
# Renamed: photo393.txt -> yayphoto556.txt
# Renamed: photo387.jpg -> yayphoto557.jpg
# Renamed: photo387.txt -> yayphoto557.txt
# Renamed: photo7.jpg -> yayphoto558.jpg
# Renamed: photo7.txt -> yayphoto558.txt
# Renamed: photo608.jpg -> yayphoto559.jpg
# Renamed: photo608.txt -> yayphoto559.txt
# Renamed: photo634.jpg -> yayphoto560.jpg
# Renamed: photo634.txt -> yayphoto560.txt
# Renamed: photo152.jpg -> yayphoto561.jpg
# Renamed: photo152.txt -> yayphoto561.txt
# Renamed: photo146.jpg -> yayphoto562.jpg
# Renamed: photo146.txt -> yayphoto562.txt
# Renamed: photo620.jpg -> yayphoto563.jpg
# Renamed: photo620.txt -> yayphoto563.txt
# Renamed: photo191.jpg -> yayphoto564.jpg
# Renamed: photo191.txt -> yayphoto564.txt
# Renamed: photo185.jpg -> yayphoto565.jpg
# Renamed: photo185.txt -> yayphoto565.txt
# Renamed: photo184.jpg -> yayphoto566.jpg
# Renamed: photo184.txt -> yayphoto566.txt
# Renamed: photo190.jpg -> yayphoto567.jpg
# Renamed: photo190.txt -> yayphoto567.txt
# Renamed: photo147.jpg -> yayphoto568.jpg
# Renamed: photo147.txt -> yayphoto568.txt
# Renamed: photo621.jpg -> yayphoto569.jpg
# Renamed: photo621.txt -> yayphoto569.txt
# Renamed: photo635.jpg -> yayphoto570.jpg
# Renamed: photo635.txt -> yayphoto570.txt
# Renamed: photo153.jpg -> yayphoto571.jpg
# Renamed: photo153.txt -> yayphoto571.txt
# Renamed: photo609.jpg -> yayphoto572.jpg
# Renamed: photo609.txt -> yayphoto572.txt
# Renamed: photo6.jpg -> yayphoto573.jpg
# Renamed: photo6.txt -> yayphoto573.txt
# Renamed: photo386.jpg -> yayphoto574.jpg
# Renamed: photo386.txt -> yayphoto574.txt
# Renamed: photo392.jpg -> yayphoto575.jpg
# Renamed: photo392.txt -> yayphoto575.txt
# Renamed: photo423.jpg -> yayphoto576.jpg
# Renamed: photo423.txt -> yayphoto576.txt
# Renamed: photo345.jpg -> yayphoto577.jpg
# Renamed: photo345.txt -> yayphoto577.txt
# Renamed: photo351.jpg -> yayphoto578.jpg
# Renamed: photo351.txt -> yayphoto578.txt
# Renamed: photo437.jpg -> yayphoto579.jpg
# Renamed: photo437.txt -> yayphoto579.txt
# Renamed: photo379.jpg -> yayphoto580.jpg
# Renamed: photo379.txt -> yayphoto580.txt
# Renamed: photo594.jpg -> yayphoto581.jpg
# Renamed: photo594.txt -> yayphoto581.txt
# Renamed: photo43.jpg -> yayphoto582.jpg
# Renamed: photo43.txt -> yayphoto582.txt
# Renamed: photo580.jpg -> yayphoto583.jpg
# Renamed: photo580.txt -> yayphoto583.txt
# Renamed: photo57.jpg -> yayphoto584.jpg
# Renamed: photo57.txt -> yayphoto584.txt
# Renamed: photo557.jpg -> yayphoto585.jpg
# Renamed: photo557.txt -> yayphoto585.txt
# Renamed: photo80.jpg -> yayphoto586.jpg
# Renamed: photo80.txt -> yayphoto586.txt
# Renamed: photo231.jpg -> yayphoto587.jpg
# Renamed: photo231.txt -> yayphoto587.txt
# Renamed: photo225.jpg -> yayphoto588.jpg
# Renamed: photo225.txt -> yayphoto588.txt
# Renamed: photo543.jpg -> yayphoto589.jpg
# Renamed: photo543.txt -> yayphoto589.txt
# Renamed: photo94.jpg -> yayphoto590.jpg
# Renamed: photo94.txt -> yayphoto590.txt
# Renamed: photo219.jpg -> yayphoto591.jpg
# Renamed: photo219.txt -> yayphoto591.txt
# Renamed: photo90.jpg -> yayphoto592.jpg
# Renamed: photo90.txt -> yayphoto592.txt
# Renamed: photo547.jpg -> yayphoto593.jpg
# Renamed: photo547.txt -> yayphoto593.txt
# Renamed: photo221.jpg -> yayphoto594.jpg
# Renamed: photo221.txt -> yayphoto594.txt
# Renamed: photo235.jpg -> yayphoto595.jpg
# Renamed: photo235.txt -> yayphoto595.txt
# Renamed: photo84.jpg -> yayphoto596.jpg
# Renamed: photo84.txt -> yayphoto596.txt
# Renamed: photo553.jpg -> yayphoto597.jpg
# Renamed: photo553.txt -> yayphoto597.txt
# Renamed: photo209.jpg -> yayphoto598.jpg
# Renamed: photo209.txt -> yayphoto598.txt
# Renamed: photo53.jpg -> yayphoto599.jpg
# Renamed: photo53.txt -> yayphoto599.txt
# Renamed: photo584.jpg -> yayphoto600.jpg
# Renamed: photo584.txt -> yayphoto600.txt
# Renamed: photo47.jpg -> yayphoto601.jpg
# Renamed: photo47.txt -> yayphoto601.txt
# Renamed: photo590.jpg -> yayphoto602.jpg
# Renamed: photo590.txt -> yayphoto602.txt
# Renamed: photo433.jpg -> yayphoto603.jpg
# Renamed: photo433.txt -> yayphoto603.txt
# Renamed: photo355.jpg -> yayphoto604.jpg
# Renamed: photo355.txt -> yayphoto604.txt
# Renamed: photo341.jpg -> yayphoto605.jpg
# Renamed: photo341.txt -> yayphoto605.txt
# Renamed: photo427.jpg -> yayphoto606.jpg
# Renamed: photo427.txt -> yayphoto606.txt
# Renamed: photo369.jpg -> yayphoto607.jpg
# Renamed: photo369.txt -> yayphoto607.txt
# Renamed: photo396.jpg -> yayphoto608.jpg
# Renamed: photo396.txt -> yayphoto608.txt
# Renamed: photo382.jpg -> yayphoto609.jpg
# Renamed: photo382.txt -> yayphoto609.txt
# Renamed: photo2.jpg -> yayphoto610.jpg
# Renamed: photo2.txt -> yayphoto610.txt
# Renamed: photo157.jpg -> yayphoto611.jpg
# Renamed: photo157.txt -> yayphoto611.txt
# Renamed: photo631.jpg -> yayphoto612.jpg
# Renamed: photo631.txt -> yayphoto612.txt
# Renamed: photo625.jpg -> yayphoto613.jpg
# Renamed: photo625.txt -> yayphoto613.txt
# Renamed: photo143.jpg -> yayphoto614.jpg
# Renamed: photo143.txt -> yayphoto614.txt
# Renamed: photo619.jpg -> yayphoto615.jpg
# Renamed: photo619.txt -> yayphoto615.txt
# Renamed: photo194.jpg -> yayphoto616.jpg
# Renamed: photo194.txt -> yayphoto616.txt
# Renamed: photo180.jpg -> yayphoto617.jpg
# Renamed: photo180.txt -> yayphoto617.txt
# Renamed: photo181.jpg -> yayphoto618.jpg
# Renamed: photo181.txt -> yayphoto618.txt
# Renamed: photo195.jpg -> yayphoto619.jpg
# Renamed: photo195.txt -> yayphoto619.txt
# Renamed: photo618.jpg -> yayphoto620.jpg
# Renamed: photo618.txt -> yayphoto620.txt
# Renamed: photo624.jpg -> yayphoto621.jpg
# Renamed: photo624.txt -> yayphoto621.txt
# Renamed: photo142.jpg -> yayphoto622.jpg
# Renamed: photo142.txt -> yayphoto622.txt
# Renamed: photo156.jpg -> yayphoto623.jpg
# Renamed: photo156.txt -> yayphoto623.txt
# Renamed: photo630.jpg -> yayphoto624.jpg
# Renamed: photo630.txt -> yayphoto624.txt
# Renamed: photo3.jpg -> yayphoto625.jpg
# Renamed: photo3.txt -> yayphoto625.txt
# Renamed: photo383.jpg -> yayphoto626.jpg
# Renamed: photo383.txt -> yayphoto626.txt
# Renamed: photo397.jpg -> yayphoto627.jpg
# Renamed: photo397.txt -> yayphoto627.txt
# Renamed: photo368.jpg -> yayphoto628.jpg
# Renamed: photo368.txt -> yayphoto628.txt
# Renamed: photo340.jpg -> yayphoto629.jpg
# Renamed: photo340.txt -> yayphoto629.txt
# Renamed: photo426.jpg -> yayphoto630.jpg
# Renamed: photo426.txt -> yayphoto630.txt
# Renamed: photo432.jpg -> yayphoto631.jpg
# Renamed: photo432.txt -> yayphoto631.txt
# Renamed: photo354.jpg -> yayphoto632.jpg
# Renamed: photo354.txt -> yayphoto632.txt
# Renamed: photo591.jpg -> yayphoto633.jpg
# Renamed: photo591.txt -> yayphoto633.txt
# Renamed: photo46.jpg -> yayphoto634.jpg
# Renamed: photo46.txt -> yayphoto634.txt
# Renamed: photo585.jpg -> yayphoto635.jpg
# Renamed: photo585.txt -> yayphoto635.txt
# Renamed: photo52.jpg -> yayphoto636.jpg
# Renamed: photo52.txt -> yayphoto636.txt
# Renamed: photo208.jpg -> yayphoto637.jpg
# Renamed: photo208.txt -> yayphoto637.txt
# Renamed: photo234.jpg -> yayphoto638.jpg
# Renamed: photo234.txt -> yayphoto638.txt
# Renamed: photo552.jpg -> yayphoto639.jpg
# Renamed: photo552.txt -> yayphoto639.txt
# Renamed: photo85.jpg -> yayphoto640.jpg
# Renamed: photo85.txt -> yayphoto640.txt
# Renamed: photo546.jpg -> yayphoto641.jpg
# Renamed: photo546.txt -> yayphoto641.txt
# Renamed: photo91.jpg -> yayphoto642.jpg
# Renamed: photo91.txt -> yayphoto642.txt
# Renamed: photo220.jpg -> yayphoto643.jpg
# Renamed: photo220.txt -> yayphoto643.txt
# Renamed: photo550.jpg -> yayphoto644.jpg
# Renamed: photo550.txt -> yayphoto644.txt
# Renamed: photo87.jpg -> yayphoto645.jpg
# Renamed: photo87.txt -> yayphoto645.txt
# Renamed: photo236.jpg -> yayphoto646.jpg
# Renamed: photo236.txt -> yayphoto646.txt
# Renamed: photo222.jpg -> yayphoto647.jpg
# Renamed: photo222.txt -> yayphoto647.txt
# Renamed: photo544.jpg -> yayphoto648.jpg
# Renamed: photo544.txt -> yayphoto648.txt
# Renamed: photo93.jpg -> yayphoto649.jpg
# Renamed: photo93.txt -> yayphoto649.txt
# Renamed: photo578.jpg -> yayphoto650.jpg
# Renamed: photo578.txt -> yayphoto650.txt
# Renamed: photo593.jpg -> yayphoto651.jpg
# Renamed: photo593.txt -> yayphoto651.txt
# Renamed: photo44.jpg -> yayphoto652.jpg
# Renamed: photo44.txt -> yayphoto652.txt
# Renamed: photo587.jpg -> yayphoto653.jpg
# Renamed: photo587.txt -> yayphoto653.txt
# Renamed: photo50.jpg -> yayphoto654.jpg
# Renamed: photo50.txt -> yayphoto654.txt
# Renamed: photo78.jpg -> yayphoto655.jpg
# Renamed: photo78.txt -> yayphoto655.txt
# Renamed: photo424.jpg -> yayphoto656.jpg
# Renamed: photo424.txt -> yayphoto656.txt
# Renamed: photo342.jpg -> yayphoto657.jpg
# Renamed: photo342.txt -> yayphoto657.txt
# Renamed: photo356.jpg -> yayphoto658.jpg
# Renamed: photo356.txt -> yayphoto658.txt
# Renamed: photo430.jpg -> yayphoto659.jpg
# Renamed: photo430.txt -> yayphoto659.txt
# Renamed: photo418.jpg -> yayphoto660.jpg
# Renamed: photo418.txt -> yayphoto660.txt
# Renamed: photo381.jpg -> yayphoto661.jpg
# Renamed: photo381.txt -> yayphoto661.txt
# Renamed: photo1.jpg -> yayphoto662.jpg
# Renamed: photo1.txt -> yayphoto662.txt
# Renamed: photo395.jpg -> yayphoto663.jpg
# Renamed: photo395.txt -> yayphoto663.txt
# Renamed: photo140.jpg -> yayphoto664.jpg
# Renamed: photo140.txt -> yayphoto664.txt
# Renamed: photo626.jpg -> yayphoto665.jpg
# Renamed: photo626.txt -> yayphoto665.txt
# Renamed: photo632.jpg -> yayphoto666.jpg
# Renamed: photo632.txt -> yayphoto666.txt
# Renamed: photo154.jpg -> yayphoto667.jpg
# Renamed: photo154.txt -> yayphoto667.txt
# Renamed: photo168.jpg -> yayphoto668.jpg
# Renamed: photo168.txt -> yayphoto668.txt
# Renamed: photo183.jpg -> yayphoto669.jpg
# Renamed: photo183.txt -> yayphoto669.txt
# Renamed: photo197.jpg -> yayphoto670.jpg
# Renamed: photo197.txt -> yayphoto670.txt
# Renamed: photo196.jpg -> yayphoto671.jpg
# Renamed: photo196.txt -> yayphoto671.txt
# Renamed: photo182.jpg -> yayphoto672.jpg
# Renamed: photo182.txt -> yayphoto672.txt
# Renamed: photo169.jpg -> yayphoto673.jpg
# Renamed: photo169.txt -> yayphoto673.txt
# Renamed: photo633.jpg -> yayphoto674.jpg
# Renamed: photo633.txt -> yayphoto674.txt
# Renamed: photo155.jpg -> yayphoto675.jpg
# Renamed: photo155.txt -> yayphoto675.txt
# Renamed: photo141.jpg -> yayphoto676.jpg
# Renamed: photo141.txt -> yayphoto676.txt
# Renamed: photo627.jpg -> yayphoto677.jpg
# Renamed: photo627.txt -> yayphoto677.txt
# Renamed: photo394.jpg -> yayphoto678.jpg
# Renamed: photo394.txt -> yayphoto678.txt
# Renamed: photo380.jpg -> yayphoto679.jpg
# Renamed: photo380.txt -> yayphoto679.txt
# Renamed: photo419.jpg -> yayphoto680.jpg
# Renamed: photo419.txt -> yayphoto680.txt
# Renamed: photo357.jpg -> yayphoto681.jpg
# Renamed: photo357.txt -> yayphoto681.txt
# Renamed: photo431.jpg -> yayphoto682.jpg
# Renamed: photo431.txt -> yayphoto682.txt
# Renamed: photo425.jpg -> yayphoto683.jpg
# Renamed: photo425.txt -> yayphoto683.txt
# Renamed: photo343.jpg -> yayphoto684.jpg
# Renamed: photo343.txt -> yayphoto684.txt
# Renamed: photo79.jpg -> yayphoto685.jpg
# Renamed: photo79.txt -> yayphoto685.txt
# Renamed: photo51.jpg -> yayphoto686.jpg
# Renamed: photo51.txt -> yayphoto686.txt
# Renamed: photo586.jpg -> yayphoto687.jpg
# Renamed: photo586.txt -> yayphoto687.txt
# Renamed: photo45.jpg -> yayphoto688.jpg
# Renamed: photo45.txt -> yayphoto688.txt
# Renamed: photo592.jpg -> yayphoto689.jpg
# Renamed: photo592.txt -> yayphoto689.txt
# Renamed: photo579.jpg -> yayphoto690.jpg
# Renamed: photo579.txt -> yayphoto690.txt
# Renamed: photo223.jpg -> yayphoto691.jpg
# Renamed: photo223.txt -> yayphoto691.txt
# Renamed: photo92.jpg -> yayphoto692.jpg
# Renamed: photo92.txt -> yayphoto692.txt
# Renamed: photo545.jpg -> yayphoto693.jpg
# Renamed: photo545.txt -> yayphoto693.txt
# Renamed: photo86.jpg -> yayphoto694.jpg
# Renamed: photo86.txt -> yayphoto694.txt
# Renamed: photo551.jpg -> yayphoto695.jpg
# Renamed: photo551.txt -> yayphoto695.txt
# Renamed: photo237.jpg -> yayphoto696.jpg
# Renamed: photo237.txt -> yayphoto696.txt

# %%
import os
import shutil

# Define folders
source_label_folder = "/Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/labels"
source_image_folder = "/Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images"
target_folder = "/Users/yatharthnehva/Downloads/new_contempt_images"

# Create target folder if it doesn't exist
os.makedirs(target_folder, exist_ok=True)

# Process each label file
for label_file in os.listdir(source_label_folder):
    if label_file.endswith(".txt"):
        label_path = os.path.join(source_label_folder, label_file)

        # Read the label file
        with open(label_path, "r") as file:
            content = file.read().strip()

        # Extract the label (first number in the file)
        label = content.split()[0]

        if label == "1":  # Check if the label is contempt
            # Construct the corresponding image path
            image_path = label_path.replace("labels", "images").replace(".txt", ".jpg")
            
            if os.path.exists(image_path):
                # Copy the image to the target folder
                shutil.copy(image_path, target_folder)
                print(f"Copied: {image_path}")
            else:
                print(f"Image not found for label file: {label_file}")

print("Processing completed.")
# Out:
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto188.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto375.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto628.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto398.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto248.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto261.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto75.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto504.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto475.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto259.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto661.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto107.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto67.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto660.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto304.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto533.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto94.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto83.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto691.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto681.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto468.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto4.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto222.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto430.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto35.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto343.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto590.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto22.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto344.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto146.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto33.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto437.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto421.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto24.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto150.jpg
# Copied: /Users/yatharthnehva/Downloads/Emotion Detection Yolov5 Pytorch/test/images/yayphoto568.jpg
# Processing completed.

# %%
import os

def rename_images_in_place(base_dir):
    for emotion_dir in os.listdir(base_dir):
        emotion_path = os.path.join(base_dir, emotion_dir)
        
        # Check if it's a directory
        if os.path.isdir(emotion_path):
            print(f"Renaming images in folder: {emotion_dir}")
            
            # List all files in the emotion folder
            images = os.listdir(emotion_path)
            for idx, img_file in enumerate(images, start=1):
                # Ensure it's a valid file
                old_path = os.path.join(emotion_path, img_file)
                if not os.path.isfile(old_path) or img_file.startswith('._'):
                    continue
                
                # Generate the new name
                new_name = f"{emotion_dir}FER_{idx}{os.path.splitext(img_file)[1]}"
                new_path = os.path.join(emotion_path, new_name)
                
                # Rename the file
                os.rename(old_path, new_path)
                print(f"Renamed: {img_file} -> {new_name}")

# Example usage
base_dir = "/Users/yatharthnehva/Downloads/disgust"  # Replace with the directory path
rename_images_in_place(base_dir)

# %%
import os

# Path to the directory containing the images
directory_path = "/Users/yatharthnehva/Downloads/disgust"

# Extract the emotion from the directory name
emotion = os.path.basename(directory_path)

# Iterate through all files in the directory
for index, filename in enumerate(os.listdir(directory_path), start=1):
    # Full path to the file
    file_path = os.path.join(directory_path, filename)
    
    # Skip if not a file
    if not os.path.isfile(file_path):
        continue

    # Get the file extension
    file_extension = os.path.splitext(filename)[-1].lower()
    
    # Skip if the file is not an image
    if file_extension not in [".jpg", ".jpeg", ".png"]:
        continue

    # New filename
    new_filename = f"FER{emotion}_{index}{file_extension}"
    new_file_path = os.path.join(directory_path, new_filename)
    
    # Rename the file
    os.rename(file_path, new_file_path)
    print(f"Renamed: {filename} → {new_filename}")

print("Renaming complete!")
# Out:
# Renamed: contemptFER_96.png → FERdisgust_1.png
# Renamed: contemptFER_82.png → FERdisgust_2.png
# Renamed: contemptFER_55.png → FERdisgust_3.png
# Renamed: contemptFER_41.png → FERdisgust_4.png
# Renamed: contemptFER_69.png → FERdisgust_5.png
# Renamed: contemptFER_4.png → FERdisgust_6.png
# Renamed: contemptFER_5.png → FERdisgust_7.png
# Renamed: contemptFER_68.png → FERdisgust_8.png
# Renamed: contemptFER_40.png → FERdisgust_9.png
# Renamed: contemptFER_54.png → FERdisgust_10.png
# Renamed: contemptFER_83.png → FERdisgust_11.png
# Renamed: contemptFER_97.png → FERdisgust_12.png
# Renamed: contemptFER_81.png → FERdisgust_13.png
# Renamed: contemptFER_95.png → FERdisgust_14.png
# Renamed: contemptFER_42.png → FERdisgust_15.png
# Renamed: contemptFER_56.png → FERdisgust_16.png
# Renamed: contemptFER_7.png → FERdisgust_17.png
# Renamed: contemptFER_6.png → FERdisgust_18.png
# Renamed: contemptFER_57.png → FERdisgust_19.png
# Renamed: contemptFER_43.png → FERdisgust_20.png
# Renamed: contemptFER_94.png → FERdisgust_21.png
# Renamed: contemptFER_80.png → FERdisgust_22.png
# Renamed: contemptFER_103.png → FERdisgust_23.png
# Renamed: contemptFER_84.png → FERdisgust_24.png
# Renamed: contemptFER_90.png → FERdisgust_25.png
# Renamed: contemptFER_47.png → FERdisgust_26.png
# Renamed: contemptFER_53.png → FERdisgust_27.png
# Renamed: contemptFER_2.png → FERdisgust_28.png
# Renamed: contemptFER_3.png → FERdisgust_30.png
# Renamed: contemptFER_52.png → FERdisgust_31.png
# Renamed: contemptFER_46.png → FERdisgust_32.png
# Renamed: contemptFER_91.png → FERdisgust_33.png
# Renamed: contemptFER_85.png → FERdisgust_34.png
# Renamed: contemptFER_102.png → FERdisgust_35.png
# Renamed: contemptFER_100.png → FERdisgust_36.png
# Renamed: contemptFER_93.png → FERdisgust_37.png
# Renamed: contemptFER_87.png → FERdisgust_38.png
# Renamed: contemptFER_78.png → FERdisgust_39.png
# Renamed: contemptFER_50.png → FERdisgust_40.png
# Renamed: contemptFER_44.png → FERdisgust_41.png
# Renamed: contemptFER_1.png → FERdisgust_42.png
# Renamed: contemptFER_45.png → FERdisgust_43.png
# Renamed: contemptFER_51.png → FERdisgust_44.png
# Renamed: contemptFER_79.png → FERdisgust_45.png
# Renamed: contemptFER_86.png → FERdisgust_46.png
# Renamed: contemptFER_92.png → FERdisgust_47.png
# Renamed: contemptFER_101.png → FERdisgust_48.png
# Renamed: contemptFER_36.png → FERdisgust_49.png
# Renamed: contemptFER_22.png → FERdisgust_50.png
# Renamed: contemptFER_23.png → FERdisgust_51.png
# Renamed: contemptFER_37.png → FERdisgust_52.png
# Renamed: contemptFER_21.png → FERdisgust_53.png
# Renamed: contemptFER_35.png → FERdisgust_54.png
# Renamed: contemptFER_34.png → FERdisgust_55.png
# Renamed: contemptFER_20.png → FERdisgust_56.png
# Renamed: contemptFER_18.png → FERdisgust_57.png
# Renamed: contemptFER_24.png → FERdisgust_58.png
# Renamed: contemptFER_30.png → FERdisgust_59.png
# Renamed: contemptFER_31.png → FERdisgust_60.png
# Renamed: contemptFER_25.png → FERdisgust_61.png
# Renamed: contemptFER_19.png → FERdisgust_62.png
# Renamed: contemptFER_33.png → FERdisgust_63.png
# Renamed: contemptFER_27.png → FERdisgust_64.png
# Renamed: contemptFER_26.png → FERdisgust_65.png
# Renamed: contemptFER_32.png → FERdisgust_66.png
# Renamed: contemptFER_17.png → FERdisgust_67.png
# Renamed: contemptFER_16.png → FERdisgust_68.png
# Renamed: contemptFER_14.png → FERdisgust_69.png
# Renamed: contemptFER_28.png → FERdisgust_70.png
# Renamed: contemptFER_29.png → FERdisgust_71.png
# Renamed: contemptFER_15.png → FERdisgust_72.png
# Renamed: contemptFER_39.png → FERdisgust_73.png
# Renamed: contemptFER_11.png → FERdisgust_74.png
# Renamed: contemptFER_10.png → FERdisgust_75.png
# Renamed: contemptFER_38.png → FERdisgust_76.png
# Renamed: contemptFER_12.png → FERdisgust_77.png
# Renamed: contemptFER_13.png → FERdisgust_78.png
# Renamed: contemptFER_74.png → FERdisgust_79.png
# Renamed: contemptFER_60.png → FERdisgust_80.png
# Renamed: contemptFER_48.png → FERdisgust_81.png
# Renamed: contemptFER_49.png → FERdisgust_82.png
# Renamed: contemptFER_61.png → FERdisgust_83.png
# Renamed: contemptFER_75.png → FERdisgust_84.png
# Renamed: contemptFER_88.png → FERdisgust_85.png
# Renamed: contemptFER_63.png → FERdisgust_86.png
# Renamed: contemptFER_77.png → FERdisgust_87.png
# Renamed: contemptFER_76.png → FERdisgust_88.png
# Renamed: contemptFER_62.png → FERdisgust_89.png
# Renamed: contemptFER_89.png → FERdisgust_90.png
# Renamed: contemptFER_99.png → FERdisgust_91.png
# Renamed: contemptFER_66.png → FERdisgust_92.png
# Renamed: contemptFER_72.png → FERdisgust_93.png
# Renamed: contemptFER_73.png → FERdisgust_94.png
# Renamed: contemptFER_67.png → FERdisgust_95.png
# Renamed: contemptFER_98.png → FERdisgust_96.png
# Renamed: contemptFER_59.png → FERdisgust_97.png
# Renamed: contemptFER_71.png → FERdisgust_98.png
# Renamed: contemptFER_65.png → FERdisgust_99.png
# Renamed: contemptFER_8.png → FERdisgust_100.png
# Renamed: contemptFER_9.png → FERdisgust_101.png
# Renamed: contemptFER_64.png → FERdisgust_102.png
# Renamed: contemptFER_70.png → FERdisgust_103.png
# Renamed: contemptFER_58.png → FERdisgust_104.png
# Renaming complete!

# %%
import os
import pandas as pd

# Define the base directory for the FER dataset
base_dir = "/Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train" 

# Initialize a list to store the information
data = []

# Iterate through the folders in the base directory
for folder_name in os.listdir(base_dir):
    folder_path = os.path.join(base_dir, folder_name)
    
    # Ensure it's a directory
    if os.path.isdir(folder_path):
        # Iterate through the images in the folder
        for image_name in os.listdir(folder_path):
            image_path = os.path.join(folder_path, image_name)
            
            # Validate that it is a file and has an appropriate extension
            if os.path.isfile(image_path) and image_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                # Append the information to the data list
                data.append({
                    "path": image_path,
                    "folder_name": folder_name,
                    "image_name": image_name,
                    "emotion": folder_name  # The folder name represents the emotion
                })

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
output_csv = "fer_train_metadata.csv"
df.to_csv(output_csv, index=False)

print(f"CSV file created successfully: {output_csv}")
# Out:
# CSV file created successfully: fer_train_metadata.csv

# %%
import pandas as pd
df = pd.read_csv("fer_train_metadata.csv")
# Specify paths
csv_path = "fer_train_metadata.csv"  # Replace with the actual CSV file path
output_csv_path = "filtered_train_csv.csv"  # Path to save the cleaned CSV

# Load the CSV
df = pd.read_csv(csv_path)

# Filter out rows with '._' in the image_path
filtered_df = df[~df['path'].str.contains(r'\._')]

# Save the filtered DataFrame to a new CSV
filtered_df.to_csv(output_csv_path, index=False)

print(f"Filtered CSV saved to {output_csv_path}")
# Out:
# Filtered CSV saved to filtered_train_csv.csv

# %%
# loading the dataset
df = pd.read_csv('filtered_train_csv.csv')

# %%
df.head()
# Out:
#                                                 path folder_name  \
# 0  /Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train...       anger
# 1  /Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train...       anger
# 2  /Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train...       anger
# 3  /Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train...       anger
# 4  /Volumes/Extreme SSD/MLPR_VIDEOS/fer2013/train...       anger
#
#        image_name emotion
# 0  fer0023473.png   anger
# 1  fer0006441.png   anger
# 2  fer0012170.png   anger
# 3  fer0018331.png   anger
# 4  fer0024126.png   anger

# %%
# number of entries per class
df['emotion'].value_counts()
# Out:
# emotion
# neutral      10308
# happiness     7528
# surprise      3562
# sadness       3514
# anger         2466
# fear           939
# disgust        750
# Name: count, dtype: int64

# %%
import os
import pandas as pd
from PIL import Image

# Define the mapping for MELD emotion labels to integer values
emotion_mapping = {
    "neutral": 0,
    "happiness": 1,
    "sadness": 2,
    "anger": 3,
    "fear": 4,
    "surprise": 5,
    "disgust": 6
}

# Load your dataset
df = pd.read_csv("filtered_train_csv.csv")

# Function to check if the file is a valid image
def is_valid_image(file_path):
    try:
        with Image.open(file_path) as img:
            img.verify()  # Check if it's a valid image
        return True
    except (IOError, SyntaxError):
        return False

# Filter valid rows
valid_rows = []
for _, row in df.iterrows():
    image_path = row['path']
    folder_name = row['folder_name']

    # Check if image path exists, is valid, and folder name is in the mapping
    if os.path.exists(image_path) and is_valid_image(image_path) and folder_name in emotion_mapping:
        row['emotion'] = emotion_mapping[folder_name]
        valid_rows.append(row)

# Create a new DataFrame with valid rows only
filtered_df = pd.DataFrame(valid_rows)

# Save the filtered dataset to a new CSV file
filtered_df.to_csv("mapped_emotions_filtered.csv", index=False)

print("Filtered dataset saved to 'mapped_emotions_filtered.csv'.")
# Out:
# Filtered dataset saved to 'mapped_emotions_filtered.csv'.

# %%
df_filtered = pd.read_csv("mapped_emotions_filtered.csv")
df_filtered.head()
df_filtered['emotion'].value_counts()
# Out:
# emotion
# 0    10308
# 1     7528
# 5     3562
# 2     3514
# 3     2466
# 4      939
# 6      750
# Name: count, dtype: int64

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.2, random_state=42)

# define transformations
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(64, scale=(0.9, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

val_test_transform = transforms.Compose([
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
class EmotionDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.transform = transform

        # Create a mapping for string labels if they exist
        if isinstance(df['emotion'].iloc[0], str):
            self.label_mapping = {label: idx for idx, label in enumerate(df['emotion'].unique())}
            self.df['emotion'] = self.df['emotion'].map(self.label_mapping)
        else:
            self.label_mapping = None

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.iloc[idx]['path']
        emotion = self.df.iloc[idx]['emotion']

        # Handle missing files
        if not os.path.exists(img_path):
            print(f"Warning: Missing file {img_path}")
            dummy_image = torch.zeros(3, 64, 64)
            return dummy_image, emotion

        try:
            image = Image.open(img_path).convert("RGB")
            if self.transform:
                image = self.transform(image)
            return image, emotion
        except Exception as e:
            print(f"Error processing {img_path}: {e}")
            dummy_image = torch.zeros(3, 64, 64)
            return dummy_image, emotion

# %%
train_dataset = EmotionDataset(train_df, transform=train_transform)
val_dataset = EmotionDataset(val_df, transform=val_test_transform)
test_dataset = EmotionDataset(test_df, transform=val_test_transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %%
class EmotionCNN(nn.Module):
    def __init__(self, num_classes, input_size=(64, 64)):
        super(EmotionCNN, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=9, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=7, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=5, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv_block4 = nn.Sequential(
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        # Dynamically compute the flattened size
        with torch.no_grad():
            dummy_input = torch.zeros(1, 3, *input_size)
            x = self.conv_block1(dummy_input)
            x = self.conv_block2(x)
            x = self.conv_block3(x)
            x = self.conv_block4(x)
            self.flattened_size = x.view(1, -1).size(1)
        print(f"Computed Flattened Size: {self.flattened_size}")

        self.fc1 = nn.Linear(self.flattened_size, 4096)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.5)
        self.fc2 = nn.Linear(4096, 256)
        self.fc3 = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = self.conv_block4(x)
        x = x.view(x.size(0), -1)  # Flatten
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
model = EmotionCNN(num_classes=7, input_size=(64, 64))
dummy_input = torch.randn(32, 3, 64, 64)
output = model(dummy_input)
print(output.shape)  # Should output: torch.Size([32, 7])
# Out:
# Computed Flattened Size: 1024
# torch.Size([32, 7])

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")

model = EmotionCNN(num_classes=7).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.5)
# Out:
# Computed Flattened Size: 1024

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler=None, epochs=50):
    best_acc = 0

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        batch_count = 0

        for i, data in enumerate(train_loader):
            try:
                images, labels = data

                # Skip empty batches
                if images is None or labels is None:
                    continue

                images, labels = images.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                batch_count += 1

                if i % 50 == 0:  # Print every 50 batches
                    print(f"Epoch {epoch+1}, Batch {i}, Loss: {loss.item():.4f}")

            except Exception as e:
                print(f"Error in batch {i}: {e}")
                continue

        # Avoid division by zero
        epoch_loss = running_loss / batch_count if batch_count > 0 else 0

        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0
        val_batch_count = 0

        with torch.no_grad():
            for data in val_loader:
                try:
                    images, labels = data

                    # Skip empty batches
                    if images is None or labels is None:
                        continue

                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_loss += loss.item()
                    val_batch_count += 1

                    _, predicted = torch.max(outputs, 1)
                    total += labels.size(0)
                    correct += (predicted == labels).sum().item()
                except Exception as e:
                    print(f"Error in validation batch: {e}")
                    continue

        # Avoid division by zero
        val_epoch_loss = val_loss / val_batch_count if val_batch_count > 0 else 0
        val_acc = 100 * correct / total if total > 0 else 0

        if val_acc > best_acc:
            best_acc = val_acc

            # Save the model state dictionary (weights only)
            torch.save(model.state_dict(), "best_model_weights.pth")

            # Save the entire model (architecture + weights)
            torch.save(model, "best_model.pth")

            print("✅ Saved new best model and weights")

        if scheduler:
            scheduler.step()

        print(f"Epoch [{epoch+1}/{epochs}], Loss: {epoch_loss:.4f}, "
              f"Val Loss: {val_epoch_loss:.4f}, Val Accuracy: {val_acc:.2f}%")

# %%
train_model(model, train_loader, val_loader, criterion, optimizer, epochs=50)
# Out:
# Epoch 1, Batch 0, Loss: 1.9630
# Epoch 1, Batch 50, Loss: 1.5604
# Epoch 1, Batch 100, Loss: 1.4405
# Epoch 1, Batch 150, Loss: 1.1333
# Epoch 1, Batch 200, Loss: 1.2400
# Epoch 1, Batch 250, Loss: 1.3752
# ✅ Saved new best model and weights
# Epoch [1/50], Loss: 1.4052, Val Loss: 1.1751, Val Accuracy: 58.55%
# Epoch 2, Batch 0, Loss: 1.1077
# Epoch 2, Batch 50, Loss: 1.0203
# Epoch 2, Batch 100, Loss: 1.0990
# Epoch 2, Batch 150, Loss: 1.0744
# Epoch 2, Batch 200, Loss: 1.0659
# Epoch 2, Batch 250, Loss: 1.0628
# ✅ Saved new best model and weights
# Epoch [2/50], Loss: 1.1409, Val Loss: 1.0492, Val Accuracy: 62.72%
# Epoch 3, Batch 0, Loss: 0.9740
# Epoch 3, Batch 50, Loss: 0.6792
# Epoch 3, Batch 100, Loss: 1.0593
# Epoch 3, Batch 150, Loss: 1.0227
# Epoch 3, Batch 200, Loss: 0.9789
# Epoch 3, Batch 250, Loss: 1.0903
# ✅ Saved new best model and weights
# Epoch [3/50], Loss: 1.0224, Val Loss: 0.9752, Val Accuracy: 65.10%
# Epoch 4, Batch 0, Loss: 1.1818
# Epoch 4, Batch 50, Loss: 0.7827
# Epoch 4, Batch 100, Loss: 1.2970
# Epoch 4, Batch 150, Loss: 1.0283
# Epoch 4, Batch 200, Loss: 1.2448
# Epoch 4, Batch 250, Loss: 0.8761
# ✅ Saved new best model and weights
# Epoch [4/50], Loss: 0.9556, Val Loss: 0.9435, Val Accuracy: 65.79%
# Epoch 5, Batch 0, Loss: 0.8714
# Epoch 5, Batch 50, Loss: 0.8787
# Epoch 5, Batch 100, Loss: 0.8294
# Epoch 5, Batch 150, Loss: 0.9957
# Epoch 5, Batch 200, Loss: 0.9563
# Epoch 5, Batch 250, Loss: 1.0384
# ✅ Saved new best model and weights
# Epoch [5/50], Loss: 0.8996, Val Loss: 0.8730, Val Accuracy: 68.76%
# Epoch 6, Batch 0, Loss: 0.9967
# Epoch 6, Batch 50, Loss: 0.7896
# Epoch 6, Batch 100, Loss: 0.9369
# Epoch 6, Batch 150, Loss: 0.6958
# Epoch 6, Batch 200, Loss: 0.7378
# Epoch 6, Batch 250, Loss: 0.8502
# Epoch [6/50], Loss: 0.8545, Val Loss: 0.8986, Val Accuracy: 67.79%
# Epoch 7, Batch 0, Loss: 0.9569
# Epoch 7, Batch 50, Loss: 1.0365
# Epoch 7, Batch 100, Loss: 0.8456
# Epoch 7, Batch 150, Loss: 0.6818
# Epoch 7, Batch 200, Loss: 0.9920
# Epoch 7, Batch 250, Loss: 0.9004
# ✅ Saved new best model and weights
# Epoch [7/50], Loss: 0.8200, Val Loss: 0.8474, Val Accuracy: 70.03%
# Epoch 8, Batch 0, Loss: 0.8582
# Epoch 8, Batch 50, Loss: 0.7106
# Epoch 8, Batch 100, Loss: 0.8048
# Epoch 8, Batch 150, Loss: 0.6118
# Epoch 8, Batch 200, Loss: 0.8377
# Epoch 8, Batch 250, Loss: 0.8234
# ✅ Saved new best model and weights
# Epoch [8/50], Loss: 0.7891, Val Loss: 0.8046, Val Accuracy: 71.58%
# Epoch 9, Batch 0, Loss: 0.6512
# Epoch 9, Batch 50, Loss: 0.8938
# Epoch 9, Batch 100, Loss: 0.6847
# Epoch 9, Batch 150, Loss: 0.7075
# Epoch 9, Batch 200, Loss: 0.8143
# Epoch 9, Batch 250, Loss: 0.5179
# Epoch [9/50], Loss: 0.7553, Val Loss: 0.8239, Val Accuracy: 71.06%
# Epoch 10, Batch 0, Loss: 0.6125
# Epoch 10, Batch 50, Loss: 0.8495
# Epoch 10, Batch 100, Loss: 0.7203
# Epoch 10, Batch 150, Loss: 0.7525
# Epoch 10, Batch 200, Loss: 0.8378
# Epoch 10, Batch 250, Loss: 0.8189
# ✅ Saved new best model and weights
# Epoch [10/50], Loss: 0.7364, Val Loss: 0.7658, Val Accuracy: 72.80%
# Epoch 11, Batch 0, Loss: 0.8144
# Epoch 11, Batch 50, Loss: 0.7825
# Epoch 11, Batch 100, Loss: 0.6974
# Epoch 11, Batch 150, Loss: 0.7891
# Epoch 11, Batch 200, Loss: 0.7813
# Epoch 11, Batch 250, Loss: 0.5925
# Epoch [11/50], Loss: 0.7016, Val Loss: 0.8163, Val Accuracy: 70.97%
# Epoch 12, Batch 0, Loss: 0.5578
# Epoch 12, Batch 50, Loss: 0.6785
# Epoch 12, Batch 100, Loss: 0.6983
# Epoch 12, Batch 150, Loss: 0.5613
# Epoch 12, Batch 200, Loss: 0.6781
# Epoch 12, Batch 250, Loss: 0.7555
# ✅ Saved new best model and weights
# Epoch [12/50], Loss: 0.6874, Val Loss: 0.7724, Val Accuracy: 73.27%
# Epoch 13, Batch 0, Loss: 0.5556
# Epoch 13, Batch 50, Loss: 0.6380
# Epoch 13, Batch 100, Loss: 0.4907
# Epoch 13, Batch 150, Loss: 0.6069
# Epoch 13, Batch 200, Loss: 0.6250
# Epoch 13, Batch 250, Loss: 0.7444
# ✅ Saved new best model and weights
# Epoch [13/50], Loss: 0.6596, Val Loss: 0.7489, Val Accuracy: 73.40%
# Epoch 14, Batch 0, Loss: 0.5281
# Epoch 14, Batch 50, Loss: 0.6395
# Epoch 14, Batch 100, Loss: 0.7158
# Epoch 14, Batch 150, Loss: 0.4972
# Epoch 14, Batch 200, Loss: 0.7770
# Epoch 14, Batch 250, Loss: 0.5650
# Epoch [14/50], Loss: 0.6468, Val Loss: 0.7731, Val Accuracy: 72.20%
# Epoch 15, Batch 0, Loss: 0.5270
# Epoch 15, Batch 50, Loss: 0.7192
# Epoch 15, Batch 100, Loss: 0.5038
# Epoch 15, Batch 150, Loss: 0.4621
# Epoch 15, Batch 200, Loss: 0.7041
# Epoch 15, Batch 250, Loss: 0.7292
# Epoch [15/50], Loss: 0.6250, Val Loss: 0.7957, Val Accuracy: 72.67%
# Epoch 16, Batch 0, Loss: 0.4589
# Epoch 16, Batch 50, Loss: 0.3988
# Epoch 16, Batch 100, Loss: 0.4180
# Epoch 16, Batch 150, Loss: 0.5968
# Epoch 16, Batch 200, Loss: 0.4969
# Epoch 16, Batch 250, Loss: 0.7042
# ✅ Saved new best model and weights
# Epoch [16/50], Loss: 0.6040, Val Loss: 0.7453, Val Accuracy: 74.26%
# Epoch 17, Batch 0, Loss: 0.5606
# Epoch 17, Batch 50, Loss: 0.6669
# Epoch 17, Batch 100, Loss: 0.6265
# Epoch 17, Batch 150, Loss: 0.6964
# Epoch 17, Batch 200, Loss: 0.5085
# Epoch 17, Batch 250, Loss: 0.8914
# Epoch [17/50], Loss: 0.5859, Val Loss: 0.7389, Val Accuracy: 73.83%
# Epoch 18, Batch 0, Loss: 0.5407
# Epoch 18, Batch 50, Loss: 0.5308
# Epoch 18, Batch 100, Loss: 0.5180
# Epoch 18, Batch 150, Loss: 0.6829
# Epoch 18, Batch 200, Loss: 0.8090
# Epoch 18, Batch 250, Loss: 0.3763
# ✅ Saved new best model and weights
# Epoch [18/50], Loss: 0.5707, Val Loss: 0.7296, Val Accuracy: 74.39%
# Epoch 19, Batch 0, Loss: 0.4645
# Epoch 19, Batch 50, Loss: 0.4726
# Epoch 19, Batch 100, Loss: 0.4553
# Epoch 19, Batch 150, Loss: 0.6856
# Epoch 19, Batch 200, Loss: 0.4885
# Epoch 19, Batch 250, Loss: 0.5804
# ✅ Saved new best model and weights
# Epoch [19/50], Loss: 0.5498, Val Loss: 0.7231, Val Accuracy: 75.25%
# Epoch 20, Batch 0, Loss: 0.6213
# Epoch 20, Batch 50, Loss: 0.6910
# Epoch 20, Batch 100, Loss: 0.5552
# Epoch 20, Batch 150, Loss: 0.4782
# Epoch 20, Batch 200, Loss: 0.5506
# Epoch 20, Batch 250, Loss: 0.5557
# Epoch [20/50], Loss: 0.5481, Val Loss: 0.7559, Val Accuracy: 74.31%
# Epoch 21, Batch 0, Loss: 0.4102
# Epoch 21, Batch 50, Loss: 0.3831
# Epoch 21, Batch 100, Loss: 0.5529
# Epoch 21, Batch 150, Loss: 0.5195
# Epoch 21, Batch 200, Loss: 0.6048
# Epoch 21, Batch 250, Loss: 0.3610
# Epoch [21/50], Loss: 0.5154, Val Loss: 0.7478, Val Accuracy: 74.69%
# Epoch 22, Batch 0, Loss: 0.3713
# Epoch 22, Batch 50, Loss: 0.4580
# Epoch 22, Batch 100, Loss: 0.6670
# Epoch 22, Batch 150, Loss: 0.4565
# Epoch 22, Batch 200, Loss: 0.3992
# Epoch 22, Batch 250, Loss: 0.5425
# Epoch [22/50], Loss: 0.5090, Val Loss: 0.7381, Val Accuracy: 74.35%
# Epoch 23, Batch 0, Loss: 0.4106
# Epoch 23, Batch 50, Loss: 0.4449
# Epoch 23, Batch 100, Loss: 0.4676
# Epoch 23, Batch 150, Loss: 0.4195
# Epoch 23, Batch 200, Loss: 0.5829
# Epoch 23, Batch 250, Loss: 0.4675
# Epoch [23/50], Loss: 0.4902, Val Loss: 0.7753, Val Accuracy: 73.92%
# Epoch 24, Batch 0, Loss: 0.3165
# Epoch 24, Batch 50, Loss: 0.5005
# Epoch 24, Batch 100, Loss: 0.6101
# Epoch 24, Batch 150, Loss: 0.6972
# Epoch 24, Batch 200, Loss: 0.4505
# Epoch 24, Batch 250, Loss: 0.5595
# Epoch [24/50], Loss: 0.4712, Val Loss: 0.7754, Val Accuracy: 74.46%
# Epoch 25, Batch 0, Loss: 0.5262
# Epoch 25, Batch 50, Loss: 0.3628
# Epoch 25, Batch 100, Loss: 0.4618
# Epoch 25, Batch 150, Loss: 0.6943
# Epoch 25, Batch 200, Loss: 0.3280
# Epoch 25, Batch 250, Loss: 0.4691
# Epoch [25/50], Loss: 0.4612, Val Loss: 0.7643, Val Accuracy: 74.26%
# Epoch 26, Batch 0, Loss: 0.3446
# Epoch 26, Batch 50, Loss: 0.3616
# Epoch 26, Batch 100, Loss: 0.4312
# Epoch 26, Batch 150, Loss: 0.6078
# Epoch 26, Batch 200, Loss: 0.3213
# Epoch 26, Batch 250, Loss: 0.5241
# Epoch [26/50], Loss: 0.4577, Val Loss: 0.7612, Val Accuracy: 74.67%
# Epoch 27, Batch 0, Loss: 0.4675
# Epoch 27, Batch 50, Loss: 0.4737
# Epoch 27, Batch 100, Loss: 0.4731
# Epoch 27, Batch 150, Loss: 0.4011
# Epoch 27, Batch 200, Loss: 0.4188
# Epoch 27, Batch 250, Loss: 0.7531
# ✅ Saved new best model and weights
# Epoch [27/50], Loss: 0.4359, Val Loss: 0.7425, Val Accuracy: 75.32%
# Epoch 28, Batch 0, Loss: 0.4062
# Epoch 28, Batch 50, Loss: 0.4120
# Epoch 28, Batch 100, Loss: 0.3721
# Epoch 28, Batch 150, Loss: 0.4103
# Epoch 28, Batch 200, Loss: 0.5832
# Epoch 28, Batch 250, Loss: 0.4611
# Epoch [28/50], Loss: 0.4228, Val Loss: 0.8101, Val Accuracy: 73.64%
# Epoch 29, Batch 0, Loss: 0.2979
# Epoch 29, Batch 50, Loss: 0.5610
# Epoch 29, Batch 100, Loss: 0.3757
# Epoch 29, Batch 150, Loss: 0.3863
# Epoch 29, Batch 200, Loss: 0.4647
# Epoch 29, Batch 250, Loss: 0.3479
# Epoch [29/50], Loss: 0.4181, Val Loss: 0.8051, Val Accuracy: 74.97%
# Epoch 30, Batch 0, Loss: 0.4541
# Epoch 30, Batch 50, Loss: 0.4131
# Epoch 30, Batch 100, Loss: 0.3087
# Epoch 30, Batch 150, Loss: 0.3373
# Epoch 30, Batch 200, Loss: 0.5041
# Epoch 30, Batch 250, Loss: 0.2733
# Epoch [30/50], Loss: 0.4015, Val Loss: 0.7863, Val Accuracy: 74.67%
# Epoch 31, Batch 0, Loss: 0.3765
# Epoch 31, Batch 50, Loss: 0.4842
# Epoch 31, Batch 100, Loss: 0.5113
# Epoch 31, Batch 150, Loss: 0.3200
# Epoch 31, Batch 200, Loss: 0.4721
# Epoch 31, Batch 250, Loss: 0.3542
# Epoch [31/50], Loss: 0.3874, Val Loss: 0.8084, Val Accuracy: 74.13%
# Epoch 32, Batch 0, Loss: 0.4337
# Epoch 32, Batch 50, Loss: 0.5893
# Epoch 32, Batch 100, Loss: 0.4373
# Epoch 32, Batch 150, Loss: 0.3582
# Epoch 32, Batch 200, Loss: 0.3529
# Epoch 32, Batch 250, Loss: 0.2499
# Epoch [32/50], Loss: 0.3855, Val Loss: 0.7882, Val Accuracy: 74.31%
# Epoch 33, Batch 0, Loss: 0.4362
# Epoch 33, Batch 50, Loss: 0.4048
# Epoch 33, Batch 100, Loss: 0.5187
# Epoch 33, Batch 150, Loss: 0.2436
# Epoch 33, Batch 200, Loss: 0.4602
# Epoch 33, Batch 250, Loss: 0.4100
# ✅ Saved new best model and weights
# Epoch [33/50], Loss: 0.3824, Val Loss: 0.7919, Val Accuracy: 75.68%
# Epoch 34, Batch 0, Loss: 0.4255
# Epoch 34, Batch 50, Loss: 0.3055
# Epoch 34, Batch 100, Loss: 0.1513
# Epoch 34, Batch 150, Loss: 0.3379
# Epoch 34, Batch 200, Loss: 0.3416
# Epoch 34, Batch 250, Loss: 0.2779
# Epoch [34/50], Loss: 0.3575, Val Loss: 0.7933, Val Accuracy: 75.68%
# Epoch 35, Batch 0, Loss: 0.3515
# Epoch 35, Batch 50, Loss: 0.3941
# Epoch 35, Batch 100, Loss: 0.4655
# Epoch 35, Batch 150, Loss: 0.2747
# Epoch 35, Batch 200, Loss: 0.3187
# Epoch 35, Batch 250, Loss: 0.2922
# Epoch [35/50], Loss: 0.3511, Val Loss: 0.8473, Val Accuracy: 75.02%
# Epoch 36, Batch 0, Loss: 0.2415
# Epoch 36, Batch 50, Loss: 0.3735
# Epoch 36, Batch 100, Loss: 0.2810
# Epoch 36, Batch 150, Loss: 0.3433
# Epoch 36, Batch 200, Loss: 0.2190
# Epoch 36, Batch 250, Loss: 0.4674
# Epoch [36/50], Loss: 0.3474, Val Loss: 0.8698, Val Accuracy: 74.16%
# Epoch 37, Batch 0, Loss: 0.4605
# Epoch 37, Batch 50, Loss: 0.2122
# Epoch 37, Batch 100, Loss: 0.3747
# Epoch 37, Batch 150, Loss: 0.3643
# Epoch 37, Batch 200, Loss: 0.3513
# Epoch 37, Batch 250, Loss: 0.2378
# Epoch [37/50], Loss: 0.3298, Val Loss: 0.8578, Val Accuracy: 74.89%
# Epoch 38, Batch 0, Loss: 0.2262
# Epoch 38, Batch 50, Loss: 0.2837
# Epoch 38, Batch 100, Loss: 0.3954
# Epoch 38, Batch 150, Loss: 0.2922
# Epoch 38, Batch 200, Loss: 0.2859
# Epoch 38, Batch 250, Loss: 0.2442
# Epoch [38/50], Loss: 0.3212, Val Loss: 0.8952, Val Accuracy: 73.10%
# Epoch 39, Batch 0, Loss: 0.2957
# Epoch 39, Batch 50, Loss: 0.2342
# Epoch 39, Batch 100, Loss: 0.3756
# Epoch 39, Batch 150, Loss: 0.3943
# Epoch 39, Batch 200, Loss: 0.2702
# Epoch 39, Batch 250, Loss: 0.2737
# Epoch [39/50], Loss: 0.3177, Val Loss: 0.8251, Val Accuracy: 75.34%
# Epoch 40, Batch 0, Loss: 0.2383
# Epoch 40, Batch 50, Loss: 0.2296
# Epoch 40, Batch 100, Loss: 0.3490
# Epoch 40, Batch 150, Loss: 0.2466
# Epoch 40, Batch 200, Loss: 0.3590
# Epoch 40, Batch 250, Loss: 0.4286
# Epoch [40/50], Loss: 0.3057, Val Loss: 0.8815, Val Accuracy: 75.19%
# Epoch 41, Batch 0, Loss: 0.2095
# Epoch 41, Batch 50, Loss: 0.3546
# Epoch 41, Batch 100, Loss: 0.1695
# Epoch 41, Batch 150, Loss: 0.2604
# Epoch 41, Batch 200, Loss: 0.3658
# Epoch 41, Batch 250, Loss: 0.4068
# Epoch [41/50], Loss: 0.3081, Val Loss: 0.8668, Val Accuracy: 74.59%
# Epoch 42, Batch 0, Loss: 0.4454
# Epoch 42, Batch 50, Loss: 0.4980
# Epoch 42, Batch 100, Loss: 0.2117
# Epoch 42, Batch 150, Loss: 0.4980
# Epoch 42, Batch 200, Loss: 0.2452
# Epoch 42, Batch 250, Loss: 0.3883
# Epoch [42/50], Loss: 0.3011, Val Loss: 0.8543, Val Accuracy: 74.74%
# Epoch 43, Batch 0, Loss: 0.3573
# Epoch 43, Batch 50, Loss: 0.2888
# Epoch 43, Batch 100, Loss: 0.2802
# Epoch 43, Batch 150, Loss: 0.3075
# Epoch 43, Batch 200, Loss: 0.2291
# Epoch 43, Batch 250, Loss: 0.3209
# Epoch [43/50], Loss: 0.2831, Val Loss: 0.8538, Val Accuracy: 74.87%
# Epoch 44, Batch 0, Loss: 0.3863
# Epoch 44, Batch 50, Loss: 0.3682
# Epoch 44, Batch 100, Loss: 0.2547
# Epoch 44, Batch 150, Loss: 0.2135
# Epoch 44, Batch 200, Loss: 0.4592
# Epoch 44, Batch 250, Loss: 0.2868
# Epoch [44/50], Loss: 0.2831, Val Loss: 0.8721, Val Accuracy: 74.65%
# Epoch 45, Batch 0, Loss: 0.2257
# Epoch 45, Batch 50, Loss: 0.3392
# Epoch 45, Batch 100, Loss: 0.1648
# Epoch 45, Batch 150, Loss: 0.2371
# Epoch 45, Batch 200, Loss: 0.1154
# Epoch 45, Batch 250, Loss: 0.3085
# Epoch [45/50], Loss: 0.2821, Val Loss: 0.8884, Val Accuracy: 74.46%
# Epoch 46, Batch 0, Loss: 0.2923
# Epoch 46, Batch 50, Loss: 0.1449
# Epoch 46, Batch 100, Loss: 0.3972
# Epoch 46, Batch 150, Loss: 0.3027
# Epoch 46, Batch 200, Loss: 0.2983
# Epoch 46, Batch 250, Loss: 0.3957
# Epoch [46/50], Loss: 0.2739, Val Loss: 0.8648, Val Accuracy: 75.45%
# Epoch 47, Batch 0, Loss: 0.2134
# Epoch 47, Batch 50, Loss: 0.1999
# Epoch 47, Batch 100, Loss: 0.1877
# Epoch 47, Batch 150, Loss: 0.3717
# Epoch 47, Batch 200, Loss: 0.3927
# Epoch 47, Batch 250, Loss: 0.3536
# Epoch [47/50], Loss: 0.2707, Val Loss: 0.9243, Val Accuracy: 74.33%
# Epoch 48, Batch 0, Loss: 0.2156
# Epoch 48, Batch 50, Loss: 0.1894
# Epoch 48, Batch 100, Loss: 0.2953
# Epoch 48, Batch 150, Loss: 0.2032
# Epoch 48, Batch 200, Loss: 0.4371
# Epoch 48, Batch 250, Loss: 0.3685
# Epoch [48/50], Loss: 0.2664, Val Loss: 0.8603, Val Accuracy: 74.87%
# Epoch 49, Batch 0, Loss: 0.3798
# Epoch 49, Batch 50, Loss: 0.2543
# Epoch 49, Batch 100, Loss: 0.1655
# Epoch 49, Batch 150, Loss: 0.2026
# Epoch 49, Batch 200, Loss: 0.1510
# Epoch 49, Batch 250, Loss: 0.3481
# Epoch [49/50], Loss: 0.2552, Val Loss: 0.9104, Val Accuracy: 75.55%
# Epoch 50, Batch 0, Loss: 0.3682
# Epoch 50, Batch 50, Loss: 0.1340
# Epoch 50, Batch 100, Loss: 0.2048
# Epoch 50, Batch 150, Loss: 0.2334
# Epoch 50, Batch 200, Loss: 0.2020
# Epoch 50, Batch 250, Loss: 0.3174
# ✅ Saved new best model and weights
# Epoch [50/50], Loss: 0.2484, Val Loss: 0.8996, Val Accuracy: 75.75%

# %%
import numpy as np
import torch
from sklearn.metrics import f1_score, classification_report

def evaluate_model(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    all_preds = []
    all_labels = []

    with torch.no_grad():  # Disable gradient computation
        for batch in test_loader:
            # Handle various batch formats
            if isinstance(batch, tuple) and len(batch) == 2:
                images, labels = batch
            elif isinstance(batch, list) and len(batch) == 2:
                images, labels = batch[0], batch[1]
            else:
                raise ValueError(f"Unexpected DataLoader batch format: {type(batch)}, content: {batch}")

            # Convert string labels to integers if needed
            if isinstance(labels[0], str):
                label_mapping = {label: idx for idx, label in enumerate(set(labels))}
                labels = [label_mapping[label] for label in labels]

            # Convert to tensors
            if not isinstance(images, torch.Tensor):
                images = torch.tensor(np.array(images), dtype=torch.float32)
            if not isinstance(labels, torch.Tensor):
                labels = torch.tensor(np.array(labels), dtype=torch.long)

            # Move data to the appropriate device
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            _, preds = torch.max(outputs, 1)  # Get predicted class indices

            # Collect predictions and true labels
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate F1 score per emotion
    f1_scores = f1_score(all_labels, all_preds, average=None)
    overall_f1 = f1_score(all_labels, all_preds, average="weighted")
    report = classification_report(all_labels, all_preds, target_names=[str(i) for i in range(len(f1_scores))])

    print(f"F1 Scores per emotion: {f1_scores}")
    print(f"Overall Weighted F1 Score: {overall_f1}")
    print("\nClassification Report:\n")
    print(report)

    return report

# %%
rep = evaluate_model(model, test_loader, device)
# Out:
# F1 Scores per emotion: [0.79208832 0.86818182 0.57486832 0.6583991  0.53631285 0.78380333
#  0.55144033]
# Overall Weighted F1 Score: 0.7610512467669835
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79      2098
#            1       0.87      0.87      0.87      1537
#            2       0.60      0.55      0.57       695
#            3       0.68      0.64      0.66       456
#            4       0.52      0.56      0.54       172
#            5       0.80      0.77      0.78       708
#            6       0.71      0.45      0.55       148
#
#     accuracy                           0.76      5814
#    macro avg       0.71      0.67      0.68      5814
# weighted avg       0.76      0.76      0.76      5814
